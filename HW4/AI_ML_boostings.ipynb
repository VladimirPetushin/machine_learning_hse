# %% [markdown]
# <a href="https://colab.research.google.com/github/Murcha1990/ML_AI25/blob/main/Lesson12_Boostings%26Interpretation/AI_ML_boostings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Градиентный бустинг
#
# #### Catboost vs. LightGBM vs. XGBoost
#
# *  Сравнение моделей на искусственном примере
# *  CatBoost для решения задачи
# *  Интерпретация модели
# *  Блендинг и стекинг

# %% [markdown]
# В прошлый раз мы посмотрели простую версию градиентного бустинга из scikit-learn, [придуманную в 1999 году Фридманом](https://projecteuclid.org/download/pdf_1/euclid.aos/1013203451). Прогресс не стоит на месте, и на сегодняшний день есть три популярные библиотеки с разными имплементациями градиентного бустинга, которые на практике показывают лушие результаты:
# *  **XGBoost**. Появилась в 2014 году, [статья автора](https://mran.microsoft.com/snapshot/2020-07-15/web/packages/xgboost/vignettes/xgboost.pdf) вышла в 2016. После выхода быстро набрала популярность и оставалась стандартом до конца 2016 года. Об особенностях данной библиотеки рассказывалось на лекции.
# * **CatBoost** от компании Яндекс с релизом в 2017 году. Алгоритм можно запускать с дефолтными гиперпараметрами, потому тчо он является менее чувствительным к выбору их конкретных значений. Отлично умеет работать с категориальным признаками, при этом автоматически обрабатывая полученные на вход непредобработанные фичи.
# * **LightGBM**. Релиз в один год с Catboost, библиотека от Microsoft. Отличается очень быстрым построением композиции. Например, при построении узла дерева, вместо перебора по всем значениям признака, производится перебор значений гистограммы этого признака. Таким образом, вместо $O(N)$ требуется $O$(m), где $m$ - число бинов гистограммы. В отличие от других библиотек, строит деревья в глубину, при этом на каждом шаге строит вершину, дающую наибольшее уменьшение функционала.

# %% [markdown]
# |Критерий|Catboost|Lightgbm|Xgboost|
# |--|--|--|--|
# |Год релиза|2014|2017|2017|
# |Построение деревьев|симметрично по уровням|в глубину|асимметрично по уровням до максимальной глубины с прунингом|
# |Параметры контроля переобучения|learning_rate, depth, l2-leaf-reg (аналога min_child_weigth нет) |learning_rate, max_depth, num_leaves, min_data_in_leaf|learning_rate (eta), min_child_weigth, max_depth|
# |Контроль скорости обучения|rsm, iterations|feature_fraction, bagging_fraction, num_iterations|n_estimator, colsample_bytree, subsample|
# |Параметры категориальных фичей|cat_features, one_hot_max_size|categorical_feature|не доступно|
# |Бинаризация признаков|сетка выбирается заранее|-|перебор всех границ, выбор сетки на каждой итерации|
# |Скор сплита|Похожесть векторов градиентов |-| Смотрим на изменение функции ошибки|
# |Bootstrap|Можно перевзвешивать и менять интенсивность |-|-|
# |Рандомизация скора сплита|+ |-|-|

# %% [markdown]
# ### Основные параметры
#
# * objective – функция ошибки для настройки композиция
# * learning_rate / eta – скорость обучения
# * n_estimators / num_iterations – число итераций градиентного бустинга
#
# ### Настройка сложности деревьев
#
# * max_depth – максимальная глубина
# * max_leaves / num_leaves – максимальное число вершин в дереве
# * gamma / min_gain_to_split – порог на уменьшение функции ошибки при расщеплении в дереве
# * min_data_in_leaf – минимальное число объектов в листе
# * min_sum_hessian_in_leaf – минимальная сумма весов объектов в листе, минимальное число объектов, при котором делается расщепление
# * lambda – коэффициент регуляризации (L2)
# * subsample / bagging_fraction – какую часть объектов обучения использовать для построения одного дерева
# * colsample_bytree / feature_fraction – какую часть признаков использовать для построения одного дерева
#
# Начать настройку можно с самых главных параметров: learning_rate и n_estimators. Один из них фиксируем, оставшийся из этих двух параметров подбираем (например, подбираем скорость обучения при n_estimators=100). Следующий параметр по важности - max_depth, так как мы хотим неглубокие деревья (в Catboost и LightGBM) для снижения переобучения.

# %% [markdown]
# **Техническое отступление**
#
# Данные библиотеки необходимо сначала устанавливать (можно через pip / conda или brew, если Вы работаете на MAC OS).
# Чтобы у Вас точно вопроизводился ноутбук и не было проблем из-за несовпадающих версий библиотек, рекомендуется через python создавать виртуальную среду. Подробнее см. файлики ```техническое_отступление.md``` и ```requirements.txt```.

# %% [markdown]
# В текущем ноутбуке использовались следующие версии библиотек:

# %%
# !pip install catboost
# !pip install lightgbm==3.2.1
# !pip install cmake==3.22.0 # без нее xgboost установится, но не будет импортироваться
# !pip install xgboost==1.5.0
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Collecting lightgbm==3.2.1
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.13.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.2.1) (1.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1) (3.5.0)
# Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.4 MB/s eta 0:00:00
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.5.0
#     Uninstalling lightgbm-4.5.0:
#       Successfully uninstalled lightgbm-4.5.0
# Successfully installed lightgbm-3.2.1
# Collecting cmake==3.22.0
#   Downloading cmake-3.22.0-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (7.3 kB)
# Downloading cmake-3.22.0-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (21.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 65.9 MB/s eta 0:00:00
# Installing collected packages: cmake
#   Attempting uninstall: cmake
#     Found existing installation: cmake 3.31.2
#     Uninstalling cmake-3.31.2:
#       Successfully uninstalled cmake-3.31.2
# Successfully installed cmake-3.22.0
# Collecting xgboost==1.5.0
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.13.1)
# Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.3
#     Uninstalling xgboost-2.1.3:
#       Successfully uninstalled xgboost-2.1.3
# Successfully installed xgboost-1.5.0

# %%
import warnings
warnings.filterwarnings('ignore')

import catboost
import lightgbm
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import xgboost

plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ## Catboost и другие бустинги для искусственного примера
#
# В алгоритме сделаны улучшения и выбор разных опций для борьбы с переобучением, подсчету сркднего таргета на отложенной выборке, подсчету статистик по категориальным фичам, бинаризацией фичей, рандомизации скора сплита, разные типы бутсрапирования.
#
# Давайте сначала зафиксируем все гиперпараметры со значениями по умолчанию, кроме количества деревьев в композиции - `n_estimators`.

# %%
def plot_surface(X, y, clf):
    h = 0.2
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    Z = Z.reshape(xx.shape)
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Добавим на график сами наблюдения
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

X, y = make_classification(n_samples=500, n_features=2, n_informative=2,
                           n_redundant=0, n_repeated=0,
                           n_classes=2, n_clusters_per_class=2,
                           flip_y=0.05, class_sep=0.8, random_state=241)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=241)

# %%
from catboost import CatBoostClassifier

catboost = CatBoostClassifier(n_estimators=300, logging_level='Silent')
catboost.fit(X_train, y_train)
plot_surface(X_test, y_test, catboost)

print(roc_auc_score(y_test, catboost.predict_proba(X_test)[:, 1]))
# Out:
# 0.919452347083926

# %%
from sklearn.ensemble import GradientBoostingClassifier

n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 600, 700, 1000, 2000]
quals_train = []
quals_test = []
for n in n_trees:
    boost = GradientBoostingClassifier(n_estimators=n)
    boost.fit(X_train, y_train)
    q_train = roc_auc_score(y_train, boost.predict_proba(X_train)[:, 1])
    q_test = roc_auc_score(y_test, boost.predict_proba(X_test)[:, 1])
    quals_train.append(q_train)
    quals_test.append(q_test)

plt.plot(n_trees, quals_train, marker='o', label='train')
plt.plot(n_trees, quals_test, marker='o', label='test')
plt.xlabel('Number of trees')
plt.ylabel('AUC-ROC')
plt.legend()
plt.show()

# %%
n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 600, 700, 1000, 2000]
quals_train = []
quals_test = []
for n in n_trees:
    catboost = CatBoostClassifier(iterations=n, logging_level='Silent')
    catboost.fit(X_train, y_train)
    q_train = roc_auc_score(y_train, catboost.predict_proba(X_train)[:, 1])
    q_test = roc_auc_score(y_test, catboost.predict_proba(X_test)[:, 1])
    quals_train.append(q_train)
    quals_test.append(q_test)

plt.plot(n_trees, quals_train, marker='o', label='train')
plt.plot(n_trees, quals_test, marker='o', label='test')
plt.xlabel('Number of trees')
plt.ylabel('AUC-ROC')
plt.legend()
plt.show()

# %% [markdown]
# ## Xgboost
#
# 1. Базовый алгоритм приближает направление, посчитанное с учетом второй производной функции потерь
#
# 2. Функционал регуляризуется – добавляются штрафы за количество листьев и за норму коэффициентов
#
# 3. При построении дерева используется критерий информативности, зависящий от оптимального вектора сдвига
#
# 4. Критерий останова при обучении дерева также зависит от оптимального сдвига
#
# Ссылка на [источник](https://github.com/esokolov/ml-course-hse/blob/master/2021-fall/lecture-notes/lecture11-ensembles.pdf)

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators=300, verbosity=0)
xgb.fit(X_train, y_train)
plot_surface(X_test, y_test, xgb)

print(roc_auc_score(y_test, xgb.predict_proba(X_test)[:, 1]))
# Out:
# 0.8745554765291608

# %%
n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 600, 700, 1000, 2000]
quals_train = []
quals_test = []
for n in n_trees:
    xgboost = XGBClassifier(n_estimators=n, verbosity=0)
    xgboost.fit(X_train, y_train)
    q_train = roc_auc_score(y_train, xgboost.predict_proba(X_train)[:, 1])
    q_test = roc_auc_score(y_test, xgboost.predict_proba(X_test)[:, 1])
    quals_train.append(q_train)
    quals_test.append(q_test)

plt.figure(figsize=(8, 5))
plt.plot(n_trees, quals_train, marker='.', label='train')
plt.plot(n_trees, quals_test, marker='.', label='test')
plt.xlabel('Number of trees')
plt.ylabel('AUC-ROC')
plt.legend()

plt.show()

# %% [markdown]
# Видно, что переобучились - качество на тесте только падает.

# %% [markdown]
# ## LightGBM

# %%
from lightgbm import LGBMClassifier

lightgbm = LGBMClassifier(n_estimators=300)
lightgbm.fit(X_train, y_train)
plot_surface(X_test, y_test, lightgbm)

print(roc_auc_score(y_test, lightgbm.predict_proba(X_test)[:, 1]))
# Out:
# 0.8733108108108107

# %%
n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 600, 700, 1000, 2000]
quals_train = []
quals_test = []
for n in n_trees:
    lightgbm = LGBMClassifier(n_estimators=n)
    lightgbm.fit(X_train, y_train)
    q_train = roc_auc_score(y_train, lightgbm.predict_proba(X_train)[:, 1])
    q_test = roc_auc_score(y_test, lightgbm.predict_proba(X_test)[:, 1])
    quals_train.append(q_train)
    quals_test.append(q_test)

plt.figure(figsize=(8, 5))
plt.plot(n_trees, quals_train, marker='o', label='train')
plt.plot(n_trees, quals_test, marker='o', label='test')
plt.xlabel('Number of trees')
plt.ylabel('AUC-ROC')
plt.legend()

plt.show()

# %% [markdown]
# В целом, у LightGBM получилась та же проблема с переобучением, как у Xgboost. Нужно дальше подбирать гиперпараметры для этих двух.

# %% [markdown]
# Попробуем взять фиксированное количество деревьев `n_estimators`, но будем менять их максимальную глубину `max_depth`. У этих алгоритмов разное время обучения, поэтому возьмем какой-то небольшой диапазон глубины и сравним все три модели - Catboost, LightGBM, Xgboost.

# %%
def plot_model_diff_depths(model=LGBMClassifier, depth_range=list(range(1, 5)), n_trees=10):
    roc_auc_train = []
    roc_auc_test = []
    for i in depth_range:
        clf = model(n_estimators=n_trees, max_depth=i)
        if type(clf) == type(CatBoostClassifier()):
            clf = CatBoostClassifier(n_estimators=n_trees, max_depth=i, logging_level="Silent")
        clf.fit(X_train, y_train)
        q_train = roc_auc_score(y_train, clf.predict_proba(X_train)[:, 1])
        q_test = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
        roc_auc_train.append(q_train)
        roc_auc_test.append(q_test)

    plt.figure(figsize=(7, 5))
    plt.plot(depth_range, roc_auc_train, marker='o', label='train')
    plt.plot(depth_range, roc_auc_test, marker='o', label='test')
    plt.title(f'{model}')
    plt.xlabel('Depth')
    plt.ylabel('AUC-ROC')
    plt.legend()

    plt.show()

# %%
plot_model_diff_depths(model=LGBMClassifier, depth_range=list(range(1, 16, 2)), n_trees=100)
plot_model_diff_depths(model=CatBoostClassifier, depth_range=list(range(1, 16, 2)), n_trees=100)
plot_model_diff_depths(model=XGBClassifier, depth_range=list(range(1, 16, 2)), n_trees=100)

# %% [markdown]
# Когда мы обучили лучшие версии моделей, можно их сохранить и использовать для получения предсказаний, например, на новом батче данных.

# %%
# Сохранить
lightgbm.booster_.save_model('lightgbm.txt')
catboost.save_model('catboost.cbm', format='cbm')
xgboost.save_model('xgboost.json')

# Загрузить
lightgbm = LGBMClassifier(model_file='mode.txt')
catboost = catboost.load_model('catboost.cbm')
xgboost = xgboost.load_model('xgboost.json')

# %% [markdown]
# ## Catboost для решения задачи + интерпретация признаков

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Murcha1990/ML_AI24/refs/heads/main/Lesson9_ClassificationBase/bike_buyers_clean.csv")

# %%
data.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
X = data.drop(['ID','Purchased Bike'], axis=1)
y = data['Purchased Bike']

# %%
X.head()
# Out:
#   Marital Status  Gender  Income  Children        Education      Occupation  \
# 0        Married  Female   40000         1        Bachelors  Skilled Manual
# 1        Married    Male   30000         3  Partial College        Clerical
# 2        Married    Male   80000         5  Partial College    Professional
# 3         Single    Male   70000         0        Bachelors    Professional
# 4         Single    Male   30000         0        Bachelors        Clerical
#
#   Home Owner  Cars Commute Distance   Region  Age
# 0        Yes     0        0-1 Miles   Europe   42
# 1        Yes     1        0-1 Miles   Europe   43
# 2         No     2        2-5 Miles   Europe   60
# 3        Yes     1       5-10 Miles  Pacific   41
# 4         No     0        0-1 Miles   Europe   36

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
from catboost import CatBoostClassifier

model1 = CatBoostClassifier(cat_features = [0, 1, 4, 5, 6, 8, 9])  # one_hot_max_size=10)
model1.fit(Xtrain, ytrain)
# Out:
# Learning rate set to 0.007663
# 0:	learn: 0.6914998	total: 34.3ms	remaining: 34.3s
# 1:	learn: 0.6896181	total: 46ms	remaining: 22.9s
# 2:	learn: 0.6886421	total: 54.8ms	remaining: 18.2s
# 3:	learn: 0.6876323	total: 63ms	remaining: 15.7s
# 4:	learn: 0.6864179	total: 80ms	remaining: 15.9s
# 5:	learn: 0.6844497	total: 89.2ms	remaining: 14.8s
# 6:	learn: 0.6836725	total: 99.6ms	remaining: 14.1s
# 7:	learn: 0.6832042	total: 101ms	remaining: 12.6s
# 8:	learn: 0.6821674	total: 110ms	remaining: 12.1s
# 9:	learn: 0.6809083	total: 128ms	remaining: 12.6s
# 10:	learn: 0.6797446	total: 145ms	remaining: 13.1s
# 11:	learn: 0.6779929	total: 158ms	remaining: 13s
# 12:	learn: 0.6770262	total: 167ms	remaining: 12.7s
# 13:	learn: 0.6760905	total: 173ms	remaining: 12.2s
# 14:	learn: 0.6756093	total: 181ms	remaining: 11.9s
# 15:	learn: 0.6748941	total: 200ms	remaining: 12.3s
# 16:	learn: 0.6731904	total: 209ms	remaining: 12.1s
# 17:	learn: 0.6721898	total: 219ms	remaining: 12s
# 18:	learn: 0.6716759	total: 222ms	remaining: 11.4s
# 19:	learn: 0.6709277	total: 231ms	remaining: 11.3s
# 20:	learn: 0.6695732	total: 241ms	remaining: 11.2s
# 21:	learn: 0.6683655	total: 251ms	remaining: 11.1s
# 22:	learn: 0.6674294	total: 260ms	remaining: 11s
# 23:	learn: 0.6663303	total: 276ms	remaining: 11.2s
# 24:	learn: 0.6656017	total: 290ms	remaining: 11.3s
# 25:	learn: 0.6647412	total: 301ms	remaining: 11.3s
# 26:	learn: 0.6643811	total: 305ms	remaining: 11s
# 27:	learn: 0.6635313	total: 321ms	remaining: 11.1s
# 28:	learn: 0.6625706	total: 334ms	remaining: 11.2s
# 29:	learn: 0.6617775	total: 341ms	remaining: 11s
# 30:	learn: 0.6609377	total: 372ms	remaining: 11.6s
# 31:	learn: 0.6600564	total: 380ms	remaining: 11.5s
# 32:	learn: 0.6593167	total: 388ms	remaining: 11.4s
# 33:	learn: 0.6584445	total: 400ms	remaining: 11.4s
# 34:	learn: 0.6573207	total: 414ms	remaining: 11.4s
# 35:	learn: 0.6568844	total: 430ms	remaining: 11.5s
# 36:	learn: 0.6556137	total: 444ms	remaining: 11.6s
# 37:	learn: 0.6545335	total: 462ms	remaining: 11.7s
# 38:	learn: 0.6535360	total: 472ms	remaining: 11.6s
# 39:	learn: 0.6520807	total: 493ms	remaining: 11.8s
# 40:	learn: 0.6512393	total: 520ms	remaining: 12.2s
# 41:	learn: 0.6507051	total: 548ms	remaining: 12.5s
# 42:	learn: 0.6495564	total: 552ms	remaining: 12.3s
# 43:	learn: 0.6483527	total: 564ms	remaining: 12.2s
# 44:	learn: 0.6477459	total: 574ms	remaining: 12.2s
# 45:	learn: 0.6475481	total: 581ms	remaining: 12s
# 46:	learn: 0.6468669	total: 589ms	remaining: 12s
# 47:	learn: 0.6457227	total: 595ms	remaining: 11.8s
# 48:	learn: 0.6443147	total: 607ms	remaining: 11.8s
# 49:	learn: 0.6433915	total: 612ms	remaining: 11.6s
# 50:	learn: 0.6422945	total: 630ms	remaining: 11.7s
# 51:	learn: 0.6410456	total: 638ms	remaining: 11.6s
# 52:	learn: 0.6394697	total: 653ms	remaining: 11.7s
# 53:	learn: 0.6382064	total: 666ms	remaining: 11.7s
# 54:	learn: 0.6374301	total: 683ms	remaining: 11.7s
# 55:	learn: 0.6359121	total: 689ms	remaining: 11.6s
# 56:	learn: 0.6350872	total: 704ms	remaining: 11.7s
# 57:	learn: 0.6345812	total: 711ms	remaining: 11.6s
# 58:	learn: 0.6335042	total: 728ms	remaining: 11.6s
# 59:	learn: 0.6328552	total: 735ms	remaining: 11.5s
# 60:	learn: 0.6322802	total: 760ms	remaining: 11.7s
# 61:	learn: 0.6318140	total: 773ms	remaining: 11.7s
# 62:	learn: 0.6311947	total: 783ms	remaining: 11.6s
# 63:	learn: 0.6304460	total: 805ms	remaining: 11.8s
# 64:	learn: 0.6294584	total: 825ms	remaining: 11.9s
# 65:	learn: 0.6284345	total: 843ms	remaining: 11.9s
# 66:	learn: 0.6279633	total: 866ms	remaining: 12.1s
# 67:	learn: 0.6269272	total: 873ms	remaining: 12s
# 68:	learn: 0.6263078	total: 882ms	remaining: 11.9s
# 69:	learn: 0.6255244	total: 899ms	remaining: 11.9s
# 70:	learn: 0.6249680	total: 903ms	remaining: 11.8s
# 71:	learn: 0.6239450	total: 907ms	remaining: 11.7s
# 72:	learn: 0.6234291	total: 911ms	remaining: 11.6s
# 73:	learn: 0.6220401	total: 919ms	remaining: 11.5s
# 74:	learn: 0.6217867	total: 921ms	remaining: 11.4s
# 75:	learn: 0.6206295	total: 925ms	remaining: 11.2s
# 76:	learn: 0.6197760	total: 953ms	remaining: 11.4s
# 77:	learn: 0.6191509	total: 961ms	remaining: 11.4s
# 78:	learn: 0.6181861	total: 968ms	remaining: 11.3s
# 79:	learn: 0.6173872	total: 973ms	remaining: 11.2s
# 80:	learn: 0.6165816	total: 977ms	remaining: 11.1s
# 81:	learn: 0.6157908	total: 981ms	remaining: 11s
# 82:	learn: 0.6152266	total: 986ms	remaining: 10.9s
# 83:	learn: 0.6137650	total: 990ms	remaining: 10.8s
# 84:	learn: 0.6134406	total: 993ms	remaining: 10.7s
# 85:	learn: 0.6128883	total: 1.02s	remaining: 10.9s
# 86:	learn: 0.6113501	total: 1.03s	remaining: 10.8s
# 87:	learn: 0.6109566	total: 1.04s	remaining: 10.8s
# 88:	learn: 0.6102371	total: 1.05s	remaining: 10.8s
# 89:	learn: 0.6094343	total: 1.06s	remaining: 10.7s
# 90:	learn: 0.6088080	total: 1.06s	remaining: 10.6s
# 91:	learn: 0.6075970	total: 1.07s	remaining: 10.5s
# 92:	learn: 0.6064158	total: 1.07s	remaining: 10.5s
# 93:	learn: 0.6059567	total: 1.08s	remaining: 10.4s
# 94:	learn: 0.6056139	total: 1.09s	remaining: 10.4s
# 95:	learn: 0.6054368	total: 1.09s	remaining: 10.3s
# 96:	learn: 0.6045354	total: 1.1s	remaining: 10.3s
# 97:	learn: 0.6042211	total: 1.11s	remaining: 10.2s
# 98:	learn: 0.6037043	total: 1.11s	remaining: 10.1s
# 99:	learn: 0.6035375	total: 1.11s	remaining: 10s
# 100:	learn: 0.6027701	total: 1.13s	remaining: 10s
# 101:	learn: 0.6015469	total: 1.14s	remaining: 10s
# 102:	learn: 0.6010520	total: 1.15s	remaining: 9.99s
# 103:	learn: 0.6003520	total: 1.15s	remaining: 9.95s
# 104:	learn: 0.5997928	total: 1.16s	remaining: 9.92s
# 105:	learn: 0.5988964	total: 1.18s	remaining: 9.92s
# 106:	learn: 0.5982551	total: 1.19s	remaining: 9.89s
# 107:	learn: 0.5978205	total: 1.19s	remaining: 9.86s
# 108:	learn: 0.5973865	total: 1.2s	remaining: 9.81s
# 109:	learn: 0.5969692	total: 1.21s	remaining: 9.82s
# 110:	learn: 0.5959817	total: 1.22s	remaining: 9.75s
# 111:	learn: 0.5951714	total: 1.22s	remaining: 9.68s
# 112:	learn: 0.5947569	total: 1.23s	remaining: 9.62s
# 113:	learn: 0.5938021	total: 1.23s	remaining: 9.6s
# 114:	learn: 0.5932227	total: 1.24s	remaining: 9.56s
# 115:	learn: 0.5927387	total: 1.25s	remaining: 9.52s
# 116:	learn: 0.5923305	total: 1.26s	remaining: 9.49s
# 117:	learn: 0.5919651	total: 1.27s	remaining: 9.46s
# 118:	learn: 0.5913061	total: 1.27s	remaining: 9.43s
# 119:	learn: 0.5903817	total: 1.28s	remaining: 9.43s
# 120:	learn: 0.5895841	total: 1.29s	remaining: 9.39s
# 121:	learn: 0.5888230	total: 1.31s	remaining: 9.4s
# 122:	learn: 0.5882681	total: 1.32s	remaining: 9.4s
# 123:	learn: 0.5874697	total: 1.32s	remaining: 9.36s
# 124:	learn: 0.5868737	total: 1.33s	remaining: 9.31s
# 125:	learn: 0.5864217	total: 1.35s	remaining: 9.34s
# 126:	learn: 0.5857430	total: 1.38s	remaining: 9.45s
# 127:	learn: 0.5852194	total: 1.39s	remaining: 9.47s
# 128:	learn: 0.5844646	total: 1.4s	remaining: 9.45s
# 129:	learn: 0.5838816	total: 1.41s	remaining: 9.43s
# 130:	learn: 0.5832903	total: 1.42s	remaining: 9.44s
# 131:	learn: 0.5826285	total: 1.43s	remaining: 9.43s
# 132:	learn: 0.5819396	total: 1.44s	remaining: 9.39s
# 133:	learn: 0.5815503	total: 1.46s	remaining: 9.42s
# 134:	learn: 0.5809616	total: 1.47s	remaining: 9.39s
# 135:	learn: 0.5803041	total: 1.48s	remaining: 9.4s
# 136:	learn: 0.5800937	total: 1.5s	remaining: 9.44s
# 137:	learn: 0.5797981	total: 1.51s	remaining: 9.42s
# 138:	learn: 0.5795403	total: 1.54s	remaining: 9.54s
# 139:	learn: 0.5792323	total: 1.55s	remaining: 9.54s
# 140:	learn: 0.5787862	total: 1.57s	remaining: 9.59s
# 141:	learn: 0.5783308	total: 1.59s	remaining: 9.61s
# 142:	learn: 0.5775645	total: 1.6s	remaining: 9.62s
# 143:	learn: 0.5768892	total: 1.62s	remaining: 9.65s
# 144:	learn: 0.5761653	total: 1.64s	remaining: 9.64s
# 145:	learn: 0.5757450	total: 1.64s	remaining: 9.61s
# 146:	learn: 0.5753911	total: 1.65s	remaining: 9.59s
# 147:	learn: 0.5748616	total: 1.66s	remaining: 9.55s
# 148:	learn: 0.5738639	total: 1.67s	remaining: 9.55s
# 149:	learn: 0.5736606	total: 1.68s	remaining: 9.5s
# 150:	learn: 0.5735008	total: 1.68s	remaining: 9.47s
# 151:	learn: 0.5726953	total: 1.7s	remaining: 9.46s
# 152:	learn: 0.5724373	total: 1.71s	remaining: 9.46s
# 153:	learn: 0.5720503	total: 1.73s	remaining: 9.52s
# 154:	learn: 0.5716737	total: 1.74s	remaining: 9.51s
# 155:	learn: 0.5709016	total: 1.77s	remaining: 9.56s
# 156:	learn: 0.5706315	total: 1.78s	remaining: 9.56s
# 157:	learn: 0.5701554	total: 1.79s	remaining: 9.55s
# 158:	learn: 0.5696879	total: 1.81s	remaining: 9.6s
# 159:	learn: 0.5690253	total: 1.82s	remaining: 9.57s
# 160:	learn: 0.5685936	total: 1.88s	remaining: 9.8s
# 161:	learn: 0.5681360	total: 1.9s	remaining: 9.84s
# 162:	learn: 0.5676294	total: 1.91s	remaining: 9.78s
# 163:	learn: 0.5672507	total: 1.92s	remaining: 9.77s
# 164:	learn: 0.5666322	total: 1.93s	remaining: 9.76s
# 165:	learn: 0.5666108	total: 1.93s	remaining: 9.7s
# 166:	learn: 0.5657911	total: 1.94s	remaining: 9.68s
# 167:	learn: 0.5652389	total: 1.96s	remaining: 9.69s
# 168:	learn: 0.5645509	total: 1.97s	remaining: 9.68s
# 169:	learn: 0.5643200	total: 1.99s	remaining: 9.7s
# 170:	learn: 0.5633268	total: 2s	remaining: 9.72s
# 171:	learn: 0.5621505	total: 2.02s	remaining: 9.74s
# 172:	learn: 0.5619239	total: 2.04s	remaining: 9.73s
# 173:	learn: 0.5615707	total: 2.05s	remaining: 9.73s
# 174:	learn: 0.5612911	total: 2.06s	remaining: 9.7s
# 175:	learn: 0.5610016	total: 2.09s	remaining: 9.79s
# 176:	learn: 0.5602668	total: 2.11s	remaining: 9.8s
# 177:	learn: 0.5598204	total: 2.13s	remaining: 9.83s
# 178:	learn: 0.5594895	total: 2.14s	remaining: 9.8s
# 179:	learn: 0.5589202	total: 2.15s	remaining: 9.8s
# 180:	learn: 0.5584361	total: 2.16s	remaining: 9.77s
# 181:	learn: 0.5582596	total: 2.17s	remaining: 9.74s
# 182:	learn: 0.5578911	total: 2.17s	remaining: 9.7s
# 183:	learn: 0.5578371	total: 2.17s	remaining: 9.65s
# 184:	learn: 0.5574103	total: 2.18s	remaining: 9.61s
# 185:	learn: 0.5569417	total: 2.19s	remaining: 9.58s
# 186:	learn: 0.5566726	total: 2.19s	remaining: 9.55s
# 187:	learn: 0.5563249	total: 2.2s	remaining: 9.52s
# 188:	learn: 0.5558025	total: 2.21s	remaining: 9.49s
# 189:	learn: 0.5554225	total: 2.22s	remaining: 9.46s
# 190:	learn: 0.5550016	total: 2.23s	remaining: 9.44s
# 191:	learn: 0.5548601	total: 2.23s	remaining: 9.4s
# 192:	learn: 0.5541915	total: 2.27s	remaining: 9.48s
# 193:	learn: 0.5539849	total: 2.28s	remaining: 9.46s
# 194:	learn: 0.5533867	total: 2.3s	remaining: 9.51s
# 195:	learn: 0.5529979	total: 2.31s	remaining: 9.49s
# 196:	learn: 0.5524835	total: 2.32s	remaining: 9.47s
# 197:	learn: 0.5519284	total: 2.33s	remaining: 9.46s
# 198:	learn: 0.5513851	total: 2.34s	remaining: 9.42s
# 199:	learn: 0.5508466	total: 2.35s	remaining: 9.42s
# 200:	learn: 0.5504924	total: 2.36s	remaining: 9.38s
# 201:	learn: 0.5501104	total: 2.38s	remaining: 9.39s
# 202:	learn: 0.5494211	total: 2.38s	remaining: 9.35s
# 203:	learn: 0.5493942	total: 2.39s	remaining: 9.32s
# 204:	learn: 0.5486605	total: 2.41s	remaining: 9.37s
# 205:	learn: 0.5477558	total: 2.43s	remaining: 9.35s
# 206:	learn: 0.5472454	total: 2.44s	remaining: 9.34s
# 207:	learn: 0.5467137	total: 2.45s	remaining: 9.35s
# 208:	learn: 0.5459549	total: 2.46s	remaining: 9.33s
# 209:	learn: 0.5456490	total: 2.48s	remaining: 9.33s
# 210:	learn: 0.5456145	total: 2.48s	remaining: 9.28s
# 211:	learn: 0.5451783	total: 2.5s	remaining: 9.31s
# 212:	learn: 0.5448057	total: 2.51s	remaining: 9.28s
# 213:	learn: 0.5447492	total: 2.52s	remaining: 9.24s
# 214:	learn: 0.5445925	total: 2.52s	remaining: 9.19s
# 215:	learn: 0.5444754	total: 2.54s	remaining: 9.2s
# 216:	learn: 0.5437499	total: 2.55s	remaining: 9.19s
# 217:	learn: 0.5435238	total: 2.56s	remaining: 9.18s
# 218:	learn: 0.5429506	total: 2.57s	remaining: 9.16s
# 219:	learn: 0.5425264	total: 2.58s	remaining: 9.15s
# 220:	learn: 0.5418383	total: 2.58s	remaining: 9.11s
# 221:	learn: 0.5415246	total: 2.59s	remaining: 9.09s
# 222:	learn: 0.5414711	total: 2.6s	remaining: 9.06s
# 223:	learn: 0.5413035	total: 2.61s	remaining: 9.04s
# 224:	learn: 0.5408586	total: 2.62s	remaining: 9.02s
# 225:	learn: 0.5406656	total: 2.62s	remaining: 8.98s
# 226:	learn: 0.5401961	total: 2.63s	remaining: 8.96s
# 227:	learn: 0.5394633	total: 2.64s	remaining: 8.94s
# 228:	learn: 0.5386959	total: 2.65s	remaining: 8.91s
# 229:	learn: 0.5383575	total: 2.65s	remaining: 8.88s
# 230:	learn: 0.5379659	total: 2.66s	remaining: 8.86s
# 231:	learn: 0.5375798	total: 2.67s	remaining: 8.85s
# 232:	learn: 0.5373667	total: 2.68s	remaining: 8.82s
# 233:	learn: 0.5372179	total: 2.69s	remaining: 8.82s
# 234:	learn: 0.5367209	total: 2.71s	remaining: 8.83s
# 235:	learn: 0.5364495	total: 2.72s	remaining: 8.8s
# 236:	learn: 0.5361536	total: 2.72s	remaining: 8.77s
# 237:	learn: 0.5357347	total: 2.73s	remaining: 8.75s
# 238:	learn: 0.5353856	total: 2.74s	remaining: 8.73s
# 239:	learn: 0.5348731	total: 2.75s	remaining: 8.71s
# 240:	learn: 0.5345028	total: 2.76s	remaining: 8.69s
# 241:	learn: 0.5338001	total: 2.77s	remaining: 8.69s
# 242:	learn: 0.5328572	total: 2.78s	remaining: 8.66s
# 243:	learn: 0.5327042	total: 2.79s	remaining: 8.65s
# 244:	learn: 0.5319535	total: 2.8s	remaining: 8.63s
# 245:	learn: 0.5315552	total: 2.81s	remaining: 8.6s
# 246:	learn: 0.5310460	total: 2.81s	remaining: 8.57s
# 247:	learn: 0.5303836	total: 2.81s	remaining: 8.53s
# 248:	learn: 0.5300135	total: 2.85s	remaining: 8.6s
# 249:	learn: 0.5297779	total: 2.87s	remaining: 8.6s
# 250:	learn: 0.5290159	total: 2.88s	remaining: 8.59s
# 251:	learn: 0.5288389	total: 2.89s	remaining: 8.57s
# 252:	learn: 0.5288119	total: 2.89s	remaining: 8.54s
# 253:	learn: 0.5284893	total: 2.9s	remaining: 8.51s
# 254:	learn: 0.5282369	total: 2.91s	remaining: 8.49s
# 255:	learn: 0.5280378	total: 2.91s	remaining: 8.47s
# 256:	learn: 0.5278364	total: 2.92s	remaining: 8.44s
# 257:	learn: 0.5276566	total: 2.93s	remaining: 8.43s
# 258:	learn: 0.5272195	total: 2.94s	remaining: 8.42s
# 259:	learn: 0.5267248	total: 2.96s	remaining: 8.41s
# 260:	learn: 0.5265066	total: 2.97s	remaining: 8.4s
# 261:	learn: 0.5260973	total: 2.98s	remaining: 8.39s
# 262:	learn: 0.5258916	total: 2.99s	remaining: 8.37s
# 263:	learn: 0.5251673	total: 3s	remaining: 8.35s
# 264:	learn: 0.5251671	total: 3s	remaining: 8.32s
# 265:	learn: 0.5247974	total: 3.01s	remaining: 8.3s
# 266:	learn: 0.5243124	total: 3.02s	remaining: 8.29s
# 267:	learn: 0.5238336	total: 3.04s	remaining: 8.3s
# 268:	learn: 0.5234882	total: 3.06s	remaining: 8.31s
# 269:	learn: 0.5232167	total: 3.07s	remaining: 8.3s
# 270:	learn: 0.5230530	total: 3.08s	remaining: 8.29s
# 271:	learn: 0.5228692	total: 3.09s	remaining: 8.27s
# 272:	learn: 0.5227328	total: 3.1s	remaining: 8.27s
# 273:	learn: 0.5224955	total: 3.12s	remaining: 8.26s
# 274:	learn: 0.5222026	total: 3.12s	remaining: 8.24s
# 275:	learn: 0.5216624	total: 3.14s	remaining: 8.24s
# 276:	learn: 0.5208685	total: 3.16s	remaining: 8.24s
# 277:	learn: 0.5205684	total: 3.17s	remaining: 8.22s
# 278:	learn: 0.5200796	total: 3.18s	remaining: 8.22s
# 279:	learn: 0.5200239	total: 3.18s	remaining: 8.19s
# 280:	learn: 0.5198291	total: 3.19s	remaining: 8.16s
# 281:	learn: 0.5192145	total: 3.2s	remaining: 8.14s
# 282:	learn: 0.5189673	total: 3.23s	remaining: 8.19s
# 283:	learn: 0.5185079	total: 3.25s	remaining: 8.18s
# 284:	learn: 0.5183194	total: 3.25s	remaining: 8.15s
# 285:	learn: 0.5176816	total: 3.26s	remaining: 8.14s
# 286:	learn: 0.5172158	total: 3.27s	remaining: 8.12s
# 287:	learn: 0.5172153	total: 3.27s	remaining: 8.1s
# 288:	learn: 0.5168580	total: 3.28s	remaining: 8.07s
# 289:	learn: 0.5165445	total: 3.3s	remaining: 8.08s
# 290:	learn: 0.5162115	total: 3.31s	remaining: 8.08s
# 291:	learn: 0.5159810	total: 3.33s	remaining: 8.06s
# 292:	learn: 0.5156013	total: 3.34s	remaining: 8.06s
# 293:	learn: 0.5152888	total: 3.35s	remaining: 8.05s
# 294:	learn: 0.5151776	total: 3.37s	remaining: 8.04s
# 295:	learn: 0.5146760	total: 3.37s	remaining: 8.03s
# 296:	learn: 0.5142768	total: 3.39s	remaining: 8.02s
# 297:	learn: 0.5139015	total: 3.4s	remaining: 8.01s
# 298:	learn: 0.5135595	total: 3.41s	remaining: 7.99s
# 299:	learn: 0.5131594	total: 3.42s	remaining: 7.98s
# 300:	learn: 0.5127666	total: 3.44s	remaining: 7.98s
# 301:	learn: 0.5125168	total: 3.44s	remaining: 7.95s
# 302:	learn: 0.5121974	total: 3.45s	remaining: 7.94s
# 303:	learn: 0.5120157	total: 3.47s	remaining: 7.95s
# 304:	learn: 0.5117441	total: 3.48s	remaining: 7.94s
# 305:	learn: 0.5116621	total: 3.49s	remaining: 7.92s
# 306:	learn: 0.5112699	total: 3.5s	remaining: 7.91s
# 307:	learn: 0.5109787	total: 3.52s	remaining: 7.9s
# 308:	learn: 0.5108554	total: 3.53s	remaining: 7.89s
# 309:	learn: 0.5104475	total: 3.54s	remaining: 7.89s
# 310:	learn: 0.5098813	total: 3.56s	remaining: 7.88s
# 311:	learn: 0.5095700	total: 3.58s	remaining: 7.9s
# 312:	learn: 0.5093416	total: 3.6s	remaining: 7.91s
# 313:	learn: 0.5091296	total: 3.61s	remaining: 7.89s
# 314:	learn: 0.5088525	total: 3.63s	remaining: 7.88s
# 315:	learn: 0.5088311	total: 3.63s	remaining: 7.86s
# 316:	learn: 0.5084256	total: 3.64s	remaining: 7.84s
# 317:	learn: 0.5082661	total: 3.66s	remaining: 7.84s
# 318:	learn: 0.5080306	total: 3.68s	remaining: 7.85s
# 319:	learn: 0.5080154	total: 3.68s	remaining: 7.82s
# 320:	learn: 0.5079832	total: 3.68s	remaining: 7.79s
# 321:	learn: 0.5078258	total: 3.69s	remaining: 7.78s
# 322:	learn: 0.5076937	total: 3.7s	remaining: 7.76s
# 323:	learn: 0.5071011	total: 3.71s	remaining: 7.74s
# 324:	learn: 0.5069701	total: 3.72s	remaining: 7.72s
# 325:	learn: 0.5068491	total: 3.73s	remaining: 7.71s
# 326:	learn: 0.5065163	total: 3.74s	remaining: 7.7s
# 327:	learn: 0.5062450	total: 3.75s	remaining: 7.68s
# 328:	learn: 0.5057498	total: 3.75s	remaining: 7.66s
# 329:	learn: 0.5056277	total: 3.77s	remaining: 7.66s
# 330:	learn: 0.5053370	total: 3.79s	remaining: 7.65s
# 331:	learn: 0.5052381	total: 3.79s	remaining: 7.64s
# 332:	learn: 0.5050291	total: 3.81s	remaining: 7.62s
# 333:	learn: 0.5044726	total: 3.84s	remaining: 7.66s
# 334:	learn: 0.5044464	total: 3.85s	remaining: 7.65s
# 335:	learn: 0.5041239	total: 3.87s	remaining: 7.64s
# 336:	learn: 0.5040976	total: 3.87s	remaining: 7.61s
# 337:	learn: 0.5040313	total: 3.88s	remaining: 7.59s
# 338:	learn: 0.5040089	total: 3.88s	remaining: 7.57s
# 339:	learn: 0.5035094	total: 3.9s	remaining: 7.58s
# 340:	learn: 0.5033090	total: 3.92s	remaining: 7.57s
# 341:	learn: 0.5029616	total: 3.93s	remaining: 7.55s
# 342:	learn: 0.5027742	total: 3.93s	remaining: 7.54s
# 343:	learn: 0.5026086	total: 3.94s	remaining: 7.52s
# 344:	learn: 0.5022077	total: 3.95s	remaining: 7.5s
# 345:	learn: 0.5020682	total: 3.96s	remaining: 7.48s
# 346:	learn: 0.5018020	total: 3.97s	remaining: 7.48s
# 347:	learn: 0.5015756	total: 3.98s	remaining: 7.47s
# 348:	learn: 0.5012755	total: 4s	remaining: 7.45s
# 349:	learn: 0.5010705	total: 4.01s	remaining: 7.45s
# 350:	learn: 0.5006020	total: 4.02s	remaining: 7.43s
# 351:	learn: 0.5000827	total: 4.03s	remaining: 7.42s
# 352:	learn: 0.4999577	total: 4.04s	remaining: 7.41s
# 353:	learn: 0.4994369	total: 4.05s	remaining: 7.4s
# 354:	learn: 0.4990150	total: 4.07s	remaining: 7.4s
# 355:	learn: 0.4987920	total: 4.08s	remaining: 7.39s
# 356:	learn: 0.4986381	total: 4.09s	remaining: 7.37s
# 357:	learn: 0.4981250	total: 4.1s	remaining: 7.36s
# 358:	learn: 0.4976056	total: 4.12s	remaining: 7.35s
# 359:	learn: 0.4974039	total: 4.13s	remaining: 7.34s
# 360:	learn: 0.4971571	total: 4.14s	remaining: 7.33s
# 361:	learn: 0.4969896	total: 4.15s	remaining: 7.31s
# 362:	learn: 0.4966522	total: 4.16s	remaining: 7.3s
# 363:	learn: 0.4961469	total: 4.17s	remaining: 7.29s
# 364:	learn: 0.4958811	total: 4.19s	remaining: 7.28s
# 365:	learn: 0.4958521	total: 4.2s	remaining: 7.27s
# 366:	learn: 0.4954662	total: 4.23s	remaining: 7.29s
# 367:	learn: 0.4949151	total: 4.24s	remaining: 7.29s
# 368:	learn: 0.4945434	total: 4.26s	remaining: 7.28s
# 369:	learn: 0.4942763	total: 4.27s	remaining: 7.27s
# 370:	learn: 0.4942763	total: 4.27s	remaining: 7.25s
# 371:	learn: 0.4937765	total: 4.29s	remaining: 7.24s
# 372:	learn: 0.4933829	total: 4.3s	remaining: 7.23s
# 373:	learn: 0.4931366	total: 4.31s	remaining: 7.22s
# 374:	learn: 0.4926691	total: 4.32s	remaining: 7.21s
# 375:	learn: 0.4923402	total: 4.33s	remaining: 7.19s
# 376:	learn: 0.4921773	total: 4.35s	remaining: 7.18s
# 377:	learn: 0.4920403	total: 4.36s	remaining: 7.17s
# 378:	learn: 0.4920294	total: 4.36s	remaining: 7.15s
# 379:	learn: 0.4916449	total: 4.38s	remaining: 7.14s
# 380:	learn: 0.4916099	total: 4.38s	remaining: 7.12s
# 381:	learn: 0.4914117	total: 4.39s	remaining: 7.11s
# 382:	learn: 0.4910694	total: 4.4s	remaining: 7.1s
# 383:	learn: 0.4906255	total: 4.42s	remaining: 7.08s
# 384:	learn: 0.4899131	total: 4.42s	remaining: 7.07s
# 385:	learn: 0.4895738	total: 4.44s	remaining: 7.06s
# 386:	learn: 0.4893123	total: 4.45s	remaining: 7.05s
# 387:	learn: 0.4889885	total: 4.46s	remaining: 7.04s
# 388:	learn: 0.4887854	total: 4.47s	remaining: 7.03s
# 389:	learn: 0.4886726	total: 4.49s	remaining: 7.01s
# 390:	learn: 0.4885915	total: 4.49s	remaining: 6.99s
# 391:	learn: 0.4884507	total: 4.5s	remaining: 6.98s
# 392:	learn: 0.4881370	total: 4.51s	remaining: 6.97s
# 393:	learn: 0.4874813	total: 4.53s	remaining: 6.97s
# 394:	learn: 0.4872776	total: 4.56s	remaining: 6.99s
# 395:	learn: 0.4867334	total: 4.58s	remaining: 6.98s
# 396:	learn: 0.4864945	total: 4.59s	remaining: 6.97s
# 397:	learn: 0.4859267	total: 4.6s	remaining: 6.96s
# 398:	learn: 0.4858982	total: 4.61s	remaining: 6.94s
# 399:	learn: 0.4856474	total: 4.63s	remaining: 6.94s
# 400:	learn: 0.4855610	total: 4.64s	remaining: 6.93s
# 401:	learn: 0.4852099	total: 4.65s	remaining: 6.91s
# 402:	learn: 0.4850098	total: 4.66s	remaining: 6.9s
# 403:	learn: 0.4848005	total: 4.67s	remaining: 6.89s
# 404:	learn: 0.4846130	total: 4.68s	remaining: 6.88s
# 405:	learn: 0.4842981	total: 4.68s	remaining: 6.86s
# 406:	learn: 0.4837300	total: 4.71s	remaining: 6.86s
# 407:	learn: 0.4832758	total: 4.72s	remaining: 6.85s
# 408:	learn: 0.4832616	total: 4.72s	remaining: 6.82s
# 409:	learn: 0.4830706	total: 4.73s	remaining: 6.81s
# 410:	learn: 0.4830063	total: 4.76s	remaining: 6.82s
# 411:	learn: 0.4827561	total: 4.78s	remaining: 6.82s
# 412:	learn: 0.4825335	total: 4.79s	remaining: 6.81s
# 413:	learn: 0.4822859	total: 4.82s	remaining: 6.82s
# 414:	learn: 0.4817332	total: 4.84s	remaining: 6.83s
# 415:	learn: 0.4814344	total: 4.86s	remaining: 6.82s
# 416:	learn: 0.4809763	total: 4.87s	remaining: 6.81s
# 417:	learn: 0.4806926	total: 4.88s	remaining: 6.8s
# 418:	learn: 0.4804723	total: 4.9s	remaining: 6.79s
# 419:	learn: 0.4801185	total: 4.91s	remaining: 6.79s
# 420:	learn: 0.4797903	total: 4.92s	remaining: 6.77s
# 421:	learn: 0.4794825	total: 4.94s	remaining: 6.76s
# 422:	learn: 0.4792087	total: 4.95s	remaining: 6.76s
# 423:	learn: 0.4788332	total: 4.96s	remaining: 6.75s
# 424:	learn: 0.4787704	total: 4.98s	remaining: 6.74s
# 425:	learn: 0.4783692	total: 5.01s	remaining: 6.75s
# 426:	learn: 0.4781138	total: 5.02s	remaining: 6.74s
# 427:	learn: 0.4778399	total: 5.06s	remaining: 6.76s
# 428:	learn: 0.4776566	total: 5.08s	remaining: 6.76s
# 429:	learn: 0.4774394	total: 5.09s	remaining: 6.75s
# 430:	learn: 0.4774117	total: 5.1s	remaining: 6.74s
# 431:	learn: 0.4773489	total: 5.12s	remaining: 6.73s
# 432:	learn: 0.4772302	total: 5.13s	remaining: 6.72s
# 433:	learn: 0.4768623	total: 5.16s	remaining: 6.73s
# 434:	learn: 0.4768583	total: 5.16s	remaining: 6.71s
# 435:	learn: 0.4766752	total: 5.17s	remaining: 6.7s
# 436:	learn: 0.4761380	total: 5.18s	remaining: 6.68s
# 437:	learn: 0.4758265	total: 5.2s	remaining: 6.67s
# 438:	learn: 0.4755098	total: 5.2s	remaining: 6.65s
# 439:	learn: 0.4755098	total: 5.21s	remaining: 6.63s
# 440:	learn: 0.4749960	total: 5.22s	remaining: 6.61s
# 441:	learn: 0.4747040	total: 5.23s	remaining: 6.61s
# 442:	learn: 0.4744711	total: 5.25s	remaining: 6.6s
# 443:	learn: 0.4742553	total: 5.26s	remaining: 6.58s
# 444:	learn: 0.4742551	total: 5.26s	remaining: 6.56s
# 445:	learn: 0.4739696	total: 5.27s	remaining: 6.55s
# 446:	learn: 0.4737962	total: 5.29s	remaining: 6.54s
# 447:	learn: 0.4736116	total: 5.29s	remaining: 6.52s
# 448:	learn: 0.4735914	total: 5.3s	remaining: 6.51s
# 449:	learn: 0.4731729	total: 5.32s	remaining: 6.5s
# 450:	learn: 0.4729596	total: 5.33s	remaining: 6.49s
# 451:	learn: 0.4725441	total: 5.34s	remaining: 6.48s
# 452:	learn: 0.4724111	total: 5.36s	remaining: 6.47s
# 453:	learn: 0.4722195	total: 5.38s	remaining: 6.47s
# 454:	learn: 0.4719224	total: 5.38s	remaining: 6.45s
# 455:	learn: 0.4717180	total: 5.41s	remaining: 6.45s
# 456:	learn: 0.4715527	total: 5.41s	remaining: 6.43s
# 457:	learn: 0.4715164	total: 5.42s	remaining: 6.42s
# 458:	learn: 0.4710675	total: 5.44s	remaining: 6.42s
# 459:	learn: 0.4708823	total: 5.46s	remaining: 6.4s
# 460:	learn: 0.4704511	total: 5.46s	remaining: 6.39s
# 461:	learn: 0.4702115	total: 5.48s	remaining: 6.38s
# 462:	learn: 0.4702110	total: 5.48s	remaining: 6.35s
# 463:	learn: 0.4701035	total: 5.5s	remaining: 6.35s
# 464:	learn: 0.4698638	total: 5.51s	remaining: 6.34s
# 465:	learn: 0.4695836	total: 5.53s	remaining: 6.34s
# 466:	learn: 0.4691460	total: 5.54s	remaining: 6.32s
# 467:	learn: 0.4691307	total: 5.54s	remaining: 6.3s
# 468:	learn: 0.4687130	total: 5.56s	remaining: 6.29s
# 469:	learn: 0.4684938	total: 5.57s	remaining: 6.29s
# 470:	learn: 0.4682188	total: 5.59s	remaining: 6.28s
# 471:	learn: 0.4677274	total: 5.61s	remaining: 6.28s
# 472:	learn: 0.4671466	total: 5.63s	remaining: 6.28s
# 473:	learn: 0.4670198	total: 5.65s	remaining: 6.27s
# 474:	learn: 0.4668375	total: 5.65s	remaining: 6.25s
# 475:	learn: 0.4666773	total: 5.67s	remaining: 6.24s
# 476:	learn: 0.4666092	total: 5.68s	remaining: 6.23s
# 477:	learn: 0.4662677	total: 5.7s	remaining: 6.23s
# 478:	learn: 0.4657649	total: 5.72s	remaining: 6.22s
# 479:	learn: 0.4655138	total: 5.73s	remaining: 6.21s
# 480:	learn: 0.4653975	total: 5.75s	remaining: 6.21s
# 481:	learn: 0.4653807	total: 5.76s	remaining: 6.19s
# 482:	learn: 0.4651907	total: 5.79s	remaining: 6.19s
# 483:	learn: 0.4650328	total: 5.8s	remaining: 6.19s
# 484:	learn: 0.4650167	total: 5.81s	remaining: 6.17s
# 485:	learn: 0.4648696	total: 5.82s	remaining: 6.16s
# 486:	learn: 0.4645548	total: 5.83s	remaining: 6.14s
# 487:	learn: 0.4643705	total: 5.84s	remaining: 6.13s
# 488:	learn: 0.4641384	total: 5.85s	remaining: 6.11s
# 489:	learn: 0.4639565	total: 5.86s	remaining: 6.1s
# 490:	learn: 0.4634585	total: 5.88s	remaining: 6.1s
# 491:	learn: 0.4633375	total: 5.89s	remaining: 6.08s
# 492:	learn: 0.4631874	total: 5.91s	remaining: 6.07s
# 493:	learn: 0.4626882	total: 5.92s	remaining: 6.06s
# 494:	learn: 0.4625952	total: 5.93s	remaining: 6.05s
# 495:	learn: 0.4622103	total: 5.93s	remaining: 6.03s
# 496:	learn: 0.4619556	total: 5.96s	remaining: 6.03s
# 497:	learn: 0.4619496	total: 5.96s	remaining: 6.01s
# 498:	learn: 0.4617628	total: 5.98s	remaining: 6s
# 499:	learn: 0.4614720	total: 6s	remaining: 6s
# 500:	learn: 0.4612797	total: 6.02s	remaining: 6s
# 501:	learn: 0.4602748	total: 6.05s	remaining: 6s
# 502:	learn: 0.4600025	total: 6.07s	remaining: 5.99s
# 503:	learn: 0.4599338	total: 6.08s	remaining: 5.99s
# 504:	learn: 0.4598837	total: 6.09s	remaining: 5.97s
# 505:	learn: 0.4597517	total: 6.11s	remaining: 5.96s
# 506:	learn: 0.4596957	total: 6.11s	remaining: 5.94s
# 507:	learn: 0.4593416	total: 6.12s	remaining: 5.93s
# 508:	learn: 0.4589404	total: 6.13s	remaining: 5.91s
# 509:	learn: 0.4585563	total: 6.15s	remaining: 5.91s
# 510:	learn: 0.4582444	total: 6.16s	remaining: 5.9s
# 511:	learn: 0.4580182	total: 6.19s	remaining: 5.9s
# 512:	learn: 0.4579300	total: 6.2s	remaining: 5.89s
# 513:	learn: 0.4573576	total: 6.22s	remaining: 5.88s
# 514:	learn: 0.4571539	total: 6.23s	remaining: 5.86s
# 515:	learn: 0.4571539	total: 6.23s	remaining: 5.85s
# 516:	learn: 0.4568042	total: 6.24s	remaining: 5.83s
# 517:	learn: 0.4563246	total: 6.26s	remaining: 5.82s
# 518:	learn: 0.4561773	total: 6.27s	remaining: 5.81s
# 519:	learn: 0.4556402	total: 6.28s	remaining: 5.79s
# 520:	learn: 0.4555236	total: 6.29s	remaining: 5.78s
# 521:	learn: 0.4553644	total: 6.32s	remaining: 5.79s
# 522:	learn: 0.4551814	total: 6.33s	remaining: 5.77s
# 523:	learn: 0.4550015	total: 6.36s	remaining: 5.77s
# 524:	learn: 0.4547603	total: 6.37s	remaining: 5.76s
# 525:	learn: 0.4546242	total: 6.39s	remaining: 5.76s
# 526:	learn: 0.4545075	total: 6.41s	remaining: 5.75s
# 527:	learn: 0.4543662	total: 6.43s	remaining: 5.75s
# 528:	learn: 0.4540628	total: 6.45s	remaining: 5.74s
# 529:	learn: 0.4539267	total: 6.45s	remaining: 5.72s
# 530:	learn: 0.4536634	total: 6.46s	remaining: 5.71s
# 531:	learn: 0.4532404	total: 6.47s	remaining: 5.69s
# 532:	learn: 0.4531773	total: 6.47s	remaining: 5.67s
# 533:	learn: 0.4531759	total: 6.48s	remaining: 5.66s
# 534:	learn: 0.4531176	total: 6.49s	remaining: 5.64s
# 535:	learn: 0.4531176	total: 6.49s	remaining: 5.62s
# 536:	learn: 0.4531176	total: 6.5s	remaining: 5.6s
# 537:	learn: 0.4529756	total: 6.51s	remaining: 5.59s
# 538:	learn: 0.4528942	total: 6.53s	remaining: 5.58s
# 539:	learn: 0.4526279	total: 6.54s	remaining: 5.57s
# 540:	learn: 0.4522690	total: 6.56s	remaining: 5.56s
# 541:	learn: 0.4519183	total: 6.57s	remaining: 5.55s
# 542:	learn: 0.4517762	total: 6.58s	remaining: 5.54s
# 543:	learn: 0.4512505	total: 6.6s	remaining: 5.53s
# 544:	learn: 0.4509747	total: 6.62s	remaining: 5.53s
# 545:	learn: 0.4508160	total: 6.62s	remaining: 5.51s
# 546:	learn: 0.4501142	total: 6.63s	remaining: 5.49s
# 547:	learn: 0.4501142	total: 6.63s	remaining: 5.47s
# 548:	learn: 0.4498106	total: 6.63s	remaining: 5.45s
# 549:	learn: 0.4498044	total: 6.63s	remaining: 5.43s
# 550:	learn: 0.4496227	total: 6.64s	remaining: 5.41s
# 551:	learn: 0.4491810	total: 6.64s	remaining: 5.39s
# 552:	learn: 0.4489715	total: 6.65s	remaining: 5.37s
# 553:	learn: 0.4489715	total: 6.65s	remaining: 5.35s
# 554:	learn: 0.4487965	total: 6.65s	remaining: 5.33s
# 555:	learn: 0.4485587	total: 6.66s	remaining: 5.32s
# 556:	learn: 0.4484140	total: 6.66s	remaining: 5.3s
# 557:	learn: 0.4481590	total: 6.66s	remaining: 5.28s
# 558:	learn: 0.4480508	total: 6.67s	remaining: 5.26s
# 559:	learn: 0.4476393	total: 6.68s	remaining: 5.25s
# 560:	learn: 0.4474196	total: 6.7s	remaining: 5.24s
# 561:	learn: 0.4471933	total: 6.74s	remaining: 5.25s
# 562:	learn: 0.4471779	total: 6.76s	remaining: 5.24s
# 563:	learn: 0.4470222	total: 6.77s	remaining: 5.24s
# 564:	learn: 0.4468538	total: 6.8s	remaining: 5.24s
# 565:	learn: 0.4466981	total: 6.81s	remaining: 5.22s
# 566:	learn: 0.4465122	total: 6.85s	remaining: 5.23s
# 567:	learn: 0.4464722	total: 6.88s	remaining: 5.23s
# 568:	learn: 0.4462875	total: 6.9s	remaining: 5.22s
# 569:	learn: 0.4461378	total: 6.91s	remaining: 5.21s
# 570:	learn: 0.4459619	total: 6.92s	remaining: 5.2s
# 571:	learn: 0.4459619	total: 6.93s	remaining: 5.19s
# 572:	learn: 0.4454840	total: 6.94s	remaining: 5.17s
# 573:	learn: 0.4452492	total: 6.96s	remaining: 5.17s
# 574:	learn: 0.4450850	total: 6.97s	remaining: 5.15s
# 575:	learn: 0.4447836	total: 6.98s	remaining: 5.14s
# 576:	learn: 0.4444588	total: 6.98s	remaining: 5.12s
# 577:	learn: 0.4441094	total: 7s	remaining: 5.11s
# 578:	learn: 0.4437214	total: 7s	remaining: 5.09s
# 579:	learn: 0.4436141	total: 7.01s	remaining: 5.07s
# 580:	learn: 0.4433323	total: 7.01s	remaining: 5.06s
# 581:	learn: 0.4431659	total: 7.01s	remaining: 5.04s
# 582:	learn: 0.4429219	total: 7.02s	remaining: 5.02s
# 583:	learn: 0.4427041	total: 7.02s	remaining: 5s
# 584:	learn: 0.4426982	total: 7.02s	remaining: 4.98s
# 585:	learn: 0.4426924	total: 7.03s	remaining: 4.96s
# 586:	learn: 0.4425432	total: 7.03s	remaining: 4.95s
# 587:	learn: 0.4423710	total: 7.04s	remaining: 4.93s
# 588:	learn: 0.4419569	total: 7.05s	remaining: 4.92s
# 589:	learn: 0.4418535	total: 7.05s	remaining: 4.9s
# 590:	learn: 0.4416844	total: 7.06s	remaining: 4.89s
# 591:	learn: 0.4414488	total: 7.07s	remaining: 4.87s
# 592:	learn: 0.4412722	total: 7.08s	remaining: 4.86s
# 593:	learn: 0.4410345	total: 7.08s	remaining: 4.84s
# 594:	learn: 0.4409210	total: 7.09s	remaining: 4.83s
# 595:	learn: 0.4405522	total: 7.1s	remaining: 4.81s
# 596:	learn: 0.4405421	total: 7.1s	remaining: 4.79s
# 597:	learn: 0.4402396	total: 7.11s	remaining: 4.78s
# 598:	learn: 0.4399280	total: 7.12s	remaining: 4.76s
# 599:	learn: 0.4399275	total: 7.12s	remaining: 4.75s
# 600:	learn: 0.4399135	total: 7.13s	remaining: 4.73s
# 601:	learn: 0.4395982	total: 7.13s	remaining: 4.72s
# 602:	learn: 0.4394142	total: 7.14s	remaining: 4.7s
# 603:	learn: 0.4392859	total: 7.15s	remaining: 4.69s
# 604:	learn: 0.4391195	total: 7.16s	remaining: 4.67s
# 605:	learn: 0.4389976	total: 7.17s	remaining: 4.66s
# 606:	learn: 0.4389321	total: 7.17s	remaining: 4.64s
# 607:	learn: 0.4386189	total: 7.18s	remaining: 4.63s
# 608:	learn: 0.4383861	total: 7.19s	remaining: 4.62s
# 609:	learn: 0.4382690	total: 7.2s	remaining: 4.6s
# 610:	learn: 0.4382427	total: 7.2s	remaining: 4.59s
# 611:	learn: 0.4381331	total: 7.21s	remaining: 4.57s
# 612:	learn: 0.4377928	total: 7.22s	remaining: 4.56s
# 613:	learn: 0.4376616	total: 7.23s	remaining: 4.54s
# 614:	learn: 0.4374733	total: 7.24s	remaining: 4.53s
# 615:	learn: 0.4371371	total: 7.25s	remaining: 4.52s
# 616:	learn: 0.4370473	total: 7.25s	remaining: 4.5s
# 617:	learn: 0.4368726	total: 7.26s	remaining: 4.49s
# 618:	learn: 0.4364217	total: 7.26s	remaining: 4.47s
# 619:	learn: 0.4358435	total: 7.27s	remaining: 4.45s
# 620:	learn: 0.4358041	total: 7.27s	remaining: 4.44s
# 621:	learn: 0.4355024	total: 7.28s	remaining: 4.42s
# 622:	learn: 0.4353276	total: 7.29s	remaining: 4.41s
# 623:	learn: 0.4350227	total: 7.31s	remaining: 4.4s
# 624:	learn: 0.4349418	total: 7.32s	remaining: 4.39s
# 625:	learn: 0.4346802	total: 7.34s	remaining: 4.38s
# 626:	learn: 0.4342150	total: 7.35s	remaining: 4.37s
# 627:	learn: 0.4340622	total: 7.37s	remaining: 4.36s
# 628:	learn: 0.4338184	total: 7.38s	remaining: 4.35s
# 629:	learn: 0.4336207	total: 7.39s	remaining: 4.34s
# 630:	learn: 0.4334708	total: 7.41s	remaining: 4.33s
# 631:	learn: 0.4333295	total: 7.42s	remaining: 4.32s
# 632:	learn: 0.4332006	total: 7.43s	remaining: 4.31s
# 633:	learn: 0.4329189	total: 7.44s	remaining: 4.29s
# 634:	learn: 0.4328932	total: 7.44s	remaining: 4.28s
# 635:	learn: 0.4327206	total: 7.45s	remaining: 4.26s
# 636:	learn: 0.4327148	total: 7.45s	remaining: 4.25s
# 637:	learn: 0.4324478	total: 7.46s	remaining: 4.23s
# 638:	learn: 0.4321784	total: 7.48s	remaining: 4.22s
# 639:	learn: 0.4320336	total: 7.48s	remaining: 4.21s
# 640:	learn: 0.4318826	total: 7.49s	remaining: 4.2s
# 641:	learn: 0.4316401	total: 7.5s	remaining: 4.18s
# 642:	learn: 0.4315125	total: 7.51s	remaining: 4.17s
# 643:	learn: 0.4313286	total: 7.51s	remaining: 4.15s
# 644:	learn: 0.4312191	total: 7.52s	remaining: 4.14s
# 645:	learn: 0.4309845	total: 7.52s	remaining: 4.12s
# 646:	learn: 0.4308503	total: 7.53s	remaining: 4.11s
# 647:	learn: 0.4306199	total: 7.53s	remaining: 4.09s
# 648:	learn: 0.4304628	total: 7.53s	remaining: 4.07s
# 649:	learn: 0.4301706	total: 7.54s	remaining: 4.06s
# 650:	learn: 0.4298467	total: 7.54s	remaining: 4.04s
# 651:	learn: 0.4296936	total: 7.54s	remaining: 4.03s
# 652:	learn: 0.4295016	total: 7.55s	remaining: 4.01s
# 653:	learn: 0.4295016	total: 7.55s	remaining: 3.99s
# 654:	learn: 0.4292639	total: 7.55s	remaining: 3.98s
# 655:	learn: 0.4288337	total: 7.56s	remaining: 3.96s
# 656:	learn: 0.4286370	total: 7.56s	remaining: 3.95s
# 657:	learn: 0.4285891	total: 7.56s	remaining: 3.93s
# 658:	learn: 0.4283966	total: 7.57s	remaining: 3.92s
# 659:	learn: 0.4279756	total: 7.57s	remaining: 3.9s
# 660:	learn: 0.4278188	total: 7.58s	remaining: 3.89s
# 661:	learn: 0.4274805	total: 7.59s	remaining: 3.88s
# 662:	learn: 0.4274243	total: 7.59s	remaining: 3.86s
# 663:	learn: 0.4271764	total: 7.61s	remaining: 3.85s
# 664:	learn: 0.4270656	total: 7.61s	remaining: 3.83s
# 665:	learn: 0.4267554	total: 7.62s	remaining: 3.82s
# 666:	learn: 0.4264246	total: 7.63s	remaining: 3.81s
# 667:	learn: 0.4263706	total: 7.64s	remaining: 3.8s
# 668:	learn: 0.4259514	total: 7.65s	remaining: 3.78s
# 669:	learn: 0.4257170	total: 7.65s	remaining: 3.77s
# 670:	learn: 0.4255538	total: 7.67s	remaining: 3.76s
# 671:	learn: 0.4254785	total: 7.68s	remaining: 3.75s
# 672:	learn: 0.4250646	total: 7.69s	remaining: 3.73s
# 673:	learn: 0.4247937	total: 7.7s	remaining: 3.72s
# 674:	learn: 0.4245120	total: 7.7s	remaining: 3.71s
# 675:	learn: 0.4242948	total: 7.71s	remaining: 3.69s
# 676:	learn: 0.4241062	total: 7.71s	remaining: 3.68s
# 677:	learn: 0.4239748	total: 7.72s	remaining: 3.67s
# 678:	learn: 0.4236139	total: 7.72s	remaining: 3.65s
# 679:	learn: 0.4236090	total: 7.72s	remaining: 3.63s
# 680:	learn: 0.4233063	total: 7.73s	remaining: 3.62s
# 681:	learn: 0.4231587	total: 7.73s	remaining: 3.6s
# 682:	learn: 0.4230351	total: 7.73s	remaining: 3.59s
# 683:	learn: 0.4228729	total: 7.74s	remaining: 3.57s
# 684:	learn: 0.4226544	total: 7.74s	remaining: 3.56s
# 685:	learn: 0.4225813	total: 7.75s	remaining: 3.54s
# 686:	learn: 0.4225813	total: 7.75s	remaining: 3.53s
# 687:	learn: 0.4224834	total: 7.75s	remaining: 3.52s
# 688:	learn: 0.4222519	total: 7.75s	remaining: 3.5s
# 689:	learn: 0.4221673	total: 7.76s	remaining: 3.49s
# 690:	learn: 0.4218240	total: 7.76s	remaining: 3.47s
# 691:	learn: 0.4216664	total: 7.76s	remaining: 3.46s
# 692:	learn: 0.4213595	total: 7.77s	remaining: 3.44s
# 693:	learn: 0.4212507	total: 7.77s	remaining: 3.43s
# 694:	learn: 0.4210824	total: 7.78s	remaining: 3.41s
# 695:	learn: 0.4209430	total: 7.78s	remaining: 3.4s
# 696:	learn: 0.4208277	total: 7.78s	remaining: 3.38s
# 697:	learn: 0.4205250	total: 7.79s	remaining: 3.37s
# 698:	learn: 0.4204403	total: 7.79s	remaining: 3.35s
# 699:	learn: 0.4201736	total: 7.79s	remaining: 3.34s
# 700:	learn: 0.4199798	total: 7.8s	remaining: 3.33s
# 701:	learn: 0.4195999	total: 7.81s	remaining: 3.32s
# 702:	learn: 0.4193969	total: 7.82s	remaining: 3.3s
# 703:	learn: 0.4191253	total: 7.83s	remaining: 3.29s
# 704:	learn: 0.4191099	total: 7.83s	remaining: 3.28s
# 705:	learn: 0.4188950	total: 7.84s	remaining: 3.26s
# 706:	learn: 0.4186631	total: 7.85s	remaining: 3.25s
# 707:	learn: 0.4184559	total: 7.86s	remaining: 3.24s
# 708:	learn: 0.4181030	total: 7.87s	remaining: 3.23s
# 709:	learn: 0.4174965	total: 7.87s	remaining: 3.22s
# 710:	learn: 0.4174965	total: 7.88s	remaining: 3.2s
# 711:	learn: 0.4173717	total: 7.89s	remaining: 3.19s
# 712:	learn: 0.4171896	total: 7.9s	remaining: 3.18s
# 713:	learn: 0.4167209	total: 7.9s	remaining: 3.17s
# 714:	learn: 0.4165639	total: 7.91s	remaining: 3.15s
# 715:	learn: 0.4163750	total: 7.91s	remaining: 3.14s
# 716:	learn: 0.4162424	total: 7.91s	remaining: 3.12s
# 717:	learn: 0.4160368	total: 7.92s	remaining: 3.11s
# 718:	learn: 0.4159441	total: 7.92s	remaining: 3.1s
# 719:	learn: 0.4156153	total: 7.93s	remaining: 3.08s
# 720:	learn: 0.4154222	total: 7.94s	remaining: 3.07s
# 721:	learn: 0.4152798	total: 7.94s	remaining: 3.06s
# 722:	learn: 0.4150693	total: 7.95s	remaining: 3.05s
# 723:	learn: 0.4150106	total: 7.96s	remaining: 3.03s
# 724:	learn: 0.4148434	total: 7.97s	remaining: 3.02s
# 725:	learn: 0.4145838	total: 7.98s	remaining: 3.01s
# 726:	learn: 0.4143958	total: 7.99s	remaining: 3s
# 727:	learn: 0.4142765	total: 8s	remaining: 2.99s
# 728:	learn: 0.4138622	total: 8.01s	remaining: 2.98s
# 729:	learn: 0.4137477	total: 8.02s	remaining: 2.96s
# 730:	learn: 0.4134736	total: 8.02s	remaining: 2.95s
# 731:	learn: 0.4132437	total: 8.03s	remaining: 2.94s
# 732:	learn: 0.4130180	total: 8.04s	remaining: 2.93s
# 733:	learn: 0.4128631	total: 8.05s	remaining: 2.92s
# 734:	learn: 0.4126998	total: 8.06s	remaining: 2.91s
# 735:	learn: 0.4125962	total: 8.07s	remaining: 2.9s
# 736:	learn: 0.4122750	total: 8.08s	remaining: 2.88s
# 737:	learn: 0.4120238	total: 8.1s	remaining: 2.88s
# 738:	learn: 0.4117606	total: 8.12s	remaining: 2.87s
# 739:	learn: 0.4116122	total: 8.12s	remaining: 2.85s
# 740:	learn: 0.4114696	total: 8.13s	remaining: 2.84s
# 741:	learn: 0.4113689	total: 8.14s	remaining: 2.83s
# 742:	learn: 0.4110534	total: 8.16s	remaining: 2.82s
# 743:	learn: 0.4109672	total: 8.16s	remaining: 2.81s
# 744:	learn: 0.4108698	total: 8.17s	remaining: 2.8s
# 745:	learn: 0.4106263	total: 8.18s	remaining: 2.78s
# 746:	learn: 0.4104108	total: 8.18s	remaining: 2.77s
# 747:	learn: 0.4099564	total: 8.19s	remaining: 2.76s
# 748:	learn: 0.4099512	total: 8.19s	remaining: 2.74s
# 749:	learn: 0.4098246	total: 8.19s	remaining: 2.73s
# 750:	learn: 0.4095959	total: 8.19s	remaining: 2.72s
# 751:	learn: 0.4094616	total: 8.2s	remaining: 2.71s
# 752:	learn: 0.4093834	total: 8.21s	remaining: 2.69s
# 753:	learn: 0.4091703	total: 8.21s	remaining: 2.68s
# 754:	learn: 0.4088503	total: 8.21s	remaining: 2.67s
# 755:	learn: 0.4088351	total: 8.22s	remaining: 2.65s
# 756:	learn: 0.4086784	total: 8.22s	remaining: 2.64s
# 757:	learn: 0.4086181	total: 8.22s	remaining: 2.63s
# 758:	learn: 0.4082705	total: 8.23s	remaining: 2.61s
# 759:	learn: 0.4080763	total: 8.23s	remaining: 2.6s
# 760:	learn: 0.4079798	total: 8.24s	remaining: 2.59s
# 761:	learn: 0.4077696	total: 8.24s	remaining: 2.57s
# 762:	learn: 0.4075664	total: 8.24s	remaining: 2.56s
# 763:	learn: 0.4072136	total: 8.25s	remaining: 2.55s
# 764:	learn: 0.4070865	total: 8.25s	remaining: 2.53s
# 765:	learn: 0.4068403	total: 8.25s	remaining: 2.52s
# 766:	learn: 0.4066678	total: 8.26s	remaining: 2.51s
# 767:	learn: 0.4064216	total: 8.26s	remaining: 2.5s
# 768:	learn: 0.4061533	total: 8.27s	remaining: 2.48s
# 769:	learn: 0.4059852	total: 8.28s	remaining: 2.47s
# 770:	learn: 0.4057766	total: 8.28s	remaining: 2.46s
# 771:	learn: 0.4057765	total: 8.29s	remaining: 2.45s
# 772:	learn: 0.4055360	total: 8.29s	remaining: 2.44s
# 773:	learn: 0.4052694	total: 8.3s	remaining: 2.42s
# 774:	learn: 0.4051964	total: 8.31s	remaining: 2.41s
# 775:	learn: 0.4046258	total: 8.32s	remaining: 2.4s
# 776:	learn: 0.4044070	total: 8.33s	remaining: 2.39s
# 777:	learn: 0.4043851	total: 8.34s	remaining: 2.38s
# 778:	learn: 0.4039792	total: 8.34s	remaining: 2.37s
# 779:	learn: 0.4038909	total: 8.35s	remaining: 2.35s
# 780:	learn: 0.4036464	total: 8.36s	remaining: 2.34s
# 781:	learn: 0.4032293	total: 8.36s	remaining: 2.33s
# 782:	learn: 0.4029277	total: 8.37s	remaining: 2.32s
# 783:	learn: 0.4026473	total: 8.37s	remaining: 2.31s
# 784:	learn: 0.4023721	total: 8.38s	remaining: 2.29s
# 785:	learn: 0.4020969	total: 8.38s	remaining: 2.28s
# 786:	learn: 0.4020513	total: 8.38s	remaining: 2.27s
# 787:	learn: 0.4017707	total: 8.39s	remaining: 2.26s
# 788:	learn: 0.4014808	total: 8.39s	remaining: 2.24s
# 789:	learn: 0.4010631	total: 8.4s	remaining: 2.23s
# 790:	learn: 0.4009713	total: 8.41s	remaining: 2.22s
# 791:	learn: 0.4007248	total: 8.41s	remaining: 2.21s
# 792:	learn: 0.4004683	total: 8.42s	remaining: 2.2s
# 793:	learn: 0.4003417	total: 8.43s	remaining: 2.19s
# 794:	learn: 0.4001544	total: 8.44s	remaining: 2.17s
# 795:	learn: 0.3999441	total: 8.45s	remaining: 2.16s
# 796:	learn: 0.3998276	total: 8.45s	remaining: 2.15s
# 797:	learn: 0.3996671	total: 8.46s	remaining: 2.14s
# 798:	learn: 0.3992172	total: 8.47s	remaining: 2.13s
# 799:	learn: 0.3990361	total: 8.48s	remaining: 2.12s
# 800:	learn: 0.3987294	total: 8.48s	remaining: 2.11s
# 801:	learn: 0.3985809	total: 8.49s	remaining: 2.1s
# 802:	learn: 0.3984590	total: 8.51s	remaining: 2.09s
# 803:	learn: 0.3982217	total: 8.52s	remaining: 2.08s
# 804:	learn: 0.3979683	total: 8.52s	remaining: 2.06s
# 805:	learn: 0.3977686	total: 8.53s	remaining: 2.05s
# 806:	learn: 0.3976151	total: 8.54s	remaining: 2.04s
# 807:	learn: 0.3975420	total: 8.55s	remaining: 2.03s
# 808:	learn: 0.3973780	total: 8.56s	remaining: 2.02s
# 809:	learn: 0.3971652	total: 8.56s	remaining: 2.01s
# 810:	learn: 0.3970620	total: 8.58s	remaining: 2s
# 811:	learn: 0.3967994	total: 8.59s	remaining: 1.99s
# 812:	learn: 0.3965316	total: 8.6s	remaining: 1.98s
# 813:	learn: 0.3963710	total: 8.6s	remaining: 1.97s
# 814:	learn: 0.3962157	total: 8.61s	remaining: 1.95s
# 815:	learn: 0.3959481	total: 8.61s	remaining: 1.94s
# 816:	learn: 0.3958194	total: 8.61s	remaining: 1.93s
# 817:	learn: 0.3956566	total: 8.62s	remaining: 1.92s
# 818:	learn: 0.3954686	total: 8.62s	remaining: 1.91s
# 819:	learn: 0.3951690	total: 8.63s	remaining: 1.89s
# 820:	learn: 0.3949814	total: 8.63s	remaining: 1.88s
# 821:	learn: 0.3948136	total: 8.63s	remaining: 1.87s
# 822:	learn: 0.3945729	total: 8.65s	remaining: 1.86s
# 823:	learn: 0.3945062	total: 8.65s	remaining: 1.85s
# 824:	learn: 0.3943075	total: 8.66s	remaining: 1.84s
# 825:	learn: 0.3939749	total: 8.67s	remaining: 1.83s
# 826:	learn: 0.3937772	total: 8.68s	remaining: 1.81s
# 827:	learn: 0.3935014	total: 8.68s	remaining: 1.8s
# 828:	learn: 0.3934047	total: 8.68s	remaining: 1.79s
# 829:	learn: 0.3932361	total: 8.69s	remaining: 1.78s
# 830:	learn: 0.3929456	total: 8.69s	remaining: 1.77s
# 831:	learn: 0.3927441	total: 8.69s	remaining: 1.75s
# 832:	learn: 0.3925508	total: 8.7s	remaining: 1.74s
# 833:	learn: 0.3923280	total: 8.7s	remaining: 1.73s
# 834:	learn: 0.3920483	total: 8.71s	remaining: 1.72s
# 835:	learn: 0.3916281	total: 8.71s	remaining: 1.71s
# 836:	learn: 0.3913482	total: 8.71s	remaining: 1.7s
# 837:	learn: 0.3911070	total: 8.72s	remaining: 1.69s
# 838:	learn: 0.3908926	total: 8.72s	remaining: 1.67s
# 839:	learn: 0.3903647	total: 8.72s	remaining: 1.66s
# 840:	learn: 0.3902289	total: 8.73s	remaining: 1.65s
# 841:	learn: 0.3900313	total: 8.73s	remaining: 1.64s
# 842:	learn: 0.3899331	total: 8.73s	remaining: 1.63s
# 843:	learn: 0.3897955	total: 8.74s	remaining: 1.61s
# 844:	learn: 0.3895477	total: 8.74s	remaining: 1.6s
# 845:	learn: 0.3893766	total: 8.75s	remaining: 1.59s
# 846:	learn: 0.3891904	total: 8.76s	remaining: 1.58s
# 847:	learn: 0.3888221	total: 8.77s	remaining: 1.57s
# 848:	learn: 0.3887207	total: 8.77s	remaining: 1.56s
# 849:	learn: 0.3885780	total: 8.77s	remaining: 1.55s
# 850:	learn: 0.3882936	total: 8.78s	remaining: 1.54s
# 851:	learn: 0.3880126	total: 8.78s	remaining: 1.52s
# 852:	learn: 0.3879157	total: 8.78s	remaining: 1.51s
# 853:	learn: 0.3878333	total: 8.79s	remaining: 1.5s
# 854:	learn: 0.3875780	total: 8.79s	remaining: 1.49s
# 855:	learn: 0.3874217	total: 8.8s	remaining: 1.48s
# 856:	learn: 0.3871125	total: 8.81s	remaining: 1.47s
# 857:	learn: 0.3868957	total: 8.81s	remaining: 1.46s
# 858:	learn: 0.3865861	total: 8.82s	remaining: 1.45s
# 859:	learn: 0.3862417	total: 8.83s	remaining: 1.44s
# 860:	learn: 0.3860407	total: 8.84s	remaining: 1.43s
# 861:	learn: 0.3855925	total: 8.85s	remaining: 1.42s
# 862:	learn: 0.3853787	total: 8.86s	remaining: 1.41s
# 863:	learn: 0.3851961	total: 8.87s	remaining: 1.4s
# 864:	learn: 0.3851687	total: 8.88s	remaining: 1.39s
# 865:	learn: 0.3849495	total: 8.88s	remaining: 1.37s
# 866:	learn: 0.3847836	total: 8.89s	remaining: 1.36s
# 867:	learn: 0.3845417	total: 8.9s	remaining: 1.35s
# 868:	learn: 0.3844963	total: 8.91s	remaining: 1.34s
# 869:	learn: 0.3843511	total: 8.91s	remaining: 1.33s
# 870:	learn: 0.3841446	total: 8.92s	remaining: 1.32s
# 871:	learn: 0.3840501	total: 8.93s	remaining: 1.31s
# 872:	learn: 0.3838539	total: 8.94s	remaining: 1.3s
# 873:	learn: 0.3837079	total: 8.95s	remaining: 1.29s
# 874:	learn: 0.3836126	total: 8.96s	remaining: 1.28s
# 875:	learn: 0.3835676	total: 8.97s	remaining: 1.27s
# 876:	learn: 0.3832339	total: 8.97s	remaining: 1.26s
# 877:	learn: 0.3831434	total: 8.98s	remaining: 1.25s
# 878:	learn: 0.3830452	total: 8.99s	remaining: 1.24s
# 879:	learn: 0.3828101	total: 9.01s	remaining: 1.23s
# 880:	learn: 0.3827849	total: 9.01s	remaining: 1.22s
# 881:	learn: 0.3827301	total: 9.02s	remaining: 1.21s
# 882:	learn: 0.3826498	total: 9.03s	remaining: 1.2s
# 883:	learn: 0.3824000	total: 9.04s	remaining: 1.19s
# 884:	learn: 0.3822433	total: 9.05s	remaining: 1.18s
# 885:	learn: 0.3820791	total: 9.06s	remaining: 1.17s
# 886:	learn: 0.3818387	total: 9.07s	remaining: 1.16s
# 887:	learn: 0.3816819	total: 9.07s	remaining: 1.14s
# 888:	learn: 0.3814576	total: 9.08s	remaining: 1.13s
# 889:	learn: 0.3813672	total: 9.09s	remaining: 1.12s
# 890:	learn: 0.3812586	total: 9.1s	remaining: 1.11s
# 891:	learn: 0.3810611	total: 9.11s	remaining: 1.1s
# 892:	learn: 0.3808101	total: 9.11s	remaining: 1.09s
# 893:	learn: 0.3807506	total: 9.12s	remaining: 1.08s
# 894:	learn: 0.3806558	total: 9.13s	remaining: 1.07s
# 895:	learn: 0.3804845	total: 9.13s	remaining: 1.06s
# 896:	learn: 0.3803914	total: 9.16s	remaining: 1.05s
# 897:	learn: 0.3800551	total: 9.16s	remaining: 1.04s
# 898:	learn: 0.3799486	total: 9.18s	remaining: 1.03s
# 899:	learn: 0.3799234	total: 9.19s	remaining: 1.02s
# 900:	learn: 0.3798709	total: 9.19s	remaining: 1.01s
# 901:	learn: 0.3797518	total: 9.2s	remaining: 999ms
# 902:	learn: 0.3795649	total: 9.21s	remaining: 989ms
# 903:	learn: 0.3793563	total: 9.21s	remaining: 978ms
# 904:	learn: 0.3792143	total: 9.23s	remaining: 969ms
# 905:	learn: 0.3791333	total: 9.23s	remaining: 958ms
# 906:	learn: 0.3788907	total: 9.24s	remaining: 948ms
# 907:	learn: 0.3785051	total: 9.25s	remaining: 937ms
# 908:	learn: 0.3782336	total: 9.26s	remaining: 927ms
# 909:	learn: 0.3776830	total: 9.27s	remaining: 917ms
# 910:	learn: 0.3774741	total: 9.28s	remaining: 906ms
# 911:	learn: 0.3771817	total: 9.29s	remaining: 896ms
# 912:	learn: 0.3770618	total: 9.29s	remaining: 886ms
# 913:	learn: 0.3770357	total: 9.3s	remaining: 875ms
# 914:	learn: 0.3769641	total: 9.31s	remaining: 865ms
# 915:	learn: 0.3765236	total: 9.32s	remaining: 854ms
# 916:	learn: 0.3762980	total: 9.32s	remaining: 844ms
# 917:	learn: 0.3759626	total: 9.33s	remaining: 834ms
# 918:	learn: 0.3759002	total: 9.34s	remaining: 823ms
# 919:	learn: 0.3755779	total: 9.35s	remaining: 813ms
# 920:	learn: 0.3754243	total: 9.36s	remaining: 803ms
# 921:	learn: 0.3751534	total: 9.37s	remaining: 793ms
# 922:	learn: 0.3749921	total: 9.38s	remaining: 782ms
# 923:	learn: 0.3749135	total: 9.38s	remaining: 772ms
# 924:	learn: 0.3747096	total: 9.39s	remaining: 762ms
# 925:	learn: 0.3745392	total: 9.41s	remaining: 752ms
# 926:	learn: 0.3742411	total: 9.41s	remaining: 741ms
# 927:	learn: 0.3739170	total: 9.42s	remaining: 731ms
# 928:	learn: 0.3737591	total: 9.43s	remaining: 721ms
# 929:	learn: 0.3732981	total: 9.44s	remaining: 711ms
# 930:	learn: 0.3728465	total: 9.45s	remaining: 700ms
# 931:	learn: 0.3727441	total: 9.48s	remaining: 692ms
# 932:	learn: 0.3724286	total: 9.5s	remaining: 682ms
# 933:	learn: 0.3723040	total: 9.51s	remaining: 672ms
# 934:	learn: 0.3722348	total: 9.52s	remaining: 662ms
# 935:	learn: 0.3719598	total: 9.53s	remaining: 651ms
# 936:	learn: 0.3717032	total: 9.54s	remaining: 641ms
# 937:	learn: 0.3715511	total: 9.54s	remaining: 631ms
# 938:	learn: 0.3711989	total: 9.55s	remaining: 621ms
# 939:	learn: 0.3710191	total: 9.56s	remaining: 610ms
# 940:	learn: 0.3708197	total: 9.57s	remaining: 600ms
# 941:	learn: 0.3706908	total: 9.58s	remaining: 590ms
# 942:	learn: 0.3705332	total: 9.59s	remaining: 580ms
# 943:	learn: 0.3703812	total: 9.6s	remaining: 569ms
# 944:	learn: 0.3702374	total: 9.6s	remaining: 559ms
# 945:	learn: 0.3701114	total: 9.61s	remaining: 549ms
# 946:	learn: 0.3700325	total: 9.62s	remaining: 538ms
# 947:	learn: 0.3697962	total: 9.63s	remaining: 528ms
# 948:	learn: 0.3696481	total: 9.63s	remaining: 518ms
# 949:	learn: 0.3694355	total: 9.64s	remaining: 507ms
# 950:	learn: 0.3692882	total: 9.65s	remaining: 497ms
# 951:	learn: 0.3691502	total: 9.66s	remaining: 487ms
# 952:	learn: 0.3690192	total: 9.67s	remaining: 477ms
# 953:	learn: 0.3688650	total: 9.68s	remaining: 467ms
# 954:	learn: 0.3686463	total: 9.68s	remaining: 456ms
# 955:	learn: 0.3685130	total: 9.69s	remaining: 446ms
# 956:	learn: 0.3680570	total: 9.71s	remaining: 436ms
# 957:	learn: 0.3679860	total: 9.71s	remaining: 426ms
# 958:	learn: 0.3675359	total: 9.73s	remaining: 416ms
# 959:	learn: 0.3674770	total: 9.73s	remaining: 406ms
# 960:	learn: 0.3673777	total: 9.75s	remaining: 396ms
# 961:	learn: 0.3670109	total: 9.75s	remaining: 385ms
# 962:	learn: 0.3668696	total: 9.76s	remaining: 375ms
# 963:	learn: 0.3667823	total: 9.77s	remaining: 365ms
# 964:	learn: 0.3665874	total: 9.78s	remaining: 355ms
# 965:	learn: 0.3665177	total: 9.8s	remaining: 345ms
# 966:	learn: 0.3662383	total: 9.81s	remaining: 335ms
# 967:	learn: 0.3661539	total: 9.82s	remaining: 325ms
# 968:	learn: 0.3659785	total: 9.84s	remaining: 315ms
# 969:	learn: 0.3657950	total: 9.84s	remaining: 304ms
# 970:	learn: 0.3656533	total: 9.86s	remaining: 295ms
# 971:	learn: 0.3655165	total: 9.87s	remaining: 284ms
# 972:	learn: 0.3653165	total: 9.88s	remaining: 274ms
# 973:	learn: 0.3652074	total: 9.89s	remaining: 264ms
# 974:	learn: 0.3647005	total: 9.9s	remaining: 254ms
# 975:	learn: 0.3645943	total: 9.91s	remaining: 244ms
# 976:	learn: 0.3644989	total: 9.92s	remaining: 234ms
# 977:	learn: 0.3642345	total: 9.94s	remaining: 224ms
# 978:	learn: 0.3640478	total: 9.95s	remaining: 213ms
# 979:	learn: 0.3635476	total: 9.95s	remaining: 203ms
# 980:	learn: 0.3633969	total: 9.96s	remaining: 193ms
# 981:	learn: 0.3632654	total: 9.97s	remaining: 183ms
# 982:	learn: 0.3630021	total: 9.98s	remaining: 173ms
# 983:	learn: 0.3628056	total: 9.99s	remaining: 162ms
# 984:	learn: 0.3626146	total: 10s	remaining: 152ms
# 985:	learn: 0.3625265	total: 10s	remaining: 142ms
# 986:	learn: 0.3622023	total: 10s	remaining: 132ms
# 987:	learn: 0.3619651	total: 10s	remaining: 122ms
# 988:	learn: 0.3618127	total: 10.1s	remaining: 112ms
# 989:	learn: 0.3617472	total: 10.1s	remaining: 102ms
# 990:	learn: 0.3615986	total: 10.1s	remaining: 91.5ms
# 991:	learn: 0.3609889	total: 10.1s	remaining: 81.5ms
# 992:	learn: 0.3605813	total: 10.1s	remaining: 71.3ms
# 993:	learn: 0.3604339	total: 10.1s	remaining: 61.2ms
# 994:	learn: 0.3600715	total: 10.1s	remaining: 51ms
# 995:	learn: 0.3595614	total: 10.2s	remaining: 40.8ms
# 996:	learn: 0.3595186	total: 10.2s	remaining: 30.6ms
# 997:	learn: 0.3592702	total: 10.2s	remaining: 20.4ms
# 998:	learn: 0.3589207	total: 10.2s	remaining: 10.2ms
# 999:	learn: 0.3588575	total: 10.2s	remaining: 0us

# %%
from sklearn.metrics import accuracy_score

pred = model1.predict(Xtest)

accuracy_score(ytest, pred)
# Out:
# 0.664

# %%
from sklearn.model_selection import GridSearchCV

params = {'max_depth' : np.arange(10,20,3),
          'learning_rate' : [0.01, 0.05, 0.1],
          'one_hot_max_size' : [10, 50, 100]}

gs = GridSearchCV(CatBoostClassifier(n_estimators=100, cat_features = [0, 1, 4, 5, 6, 8, 9], verbose=0), params, cv=3, scoring='accuracy', verbose=2)

gs.fit(Xtrain, ytrain)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=10; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=10; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=50; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=50; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=10; total time=  11.2s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=10; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=10; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=50; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=50; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=50; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=100; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=100; total time=   7.4s
# [CV] END learning_rate=0.01, max_depth=16, one_hot_max_size=100; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=10; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=10; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=10; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=50; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=50; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=13, one_hot_max_size=100; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=10; total time=   5.4s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=10; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=10; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=50; total time=   6.6s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=50; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=50; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=100; total time=   6.3s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=100; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=16, one_hot_max_size=100; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=10; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=50; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=100; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=10, one_hot_max_size=100; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=10; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=10; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=10; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=100; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=13, one_hot_max_size=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=10; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=10; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=10; total time=  10.3s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=50; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=50; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=50; total time=   6.6s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=100; total time=   7.9s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=100; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=16, one_hot_max_size=100; total time=   7.2s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=19, one_hot_max_size=100; total time=   0.0s
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostClassifier object at 0x7912ed53af20>,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': array([10, 13, 16, 19]),
#                          'one_hot_max_size': [10, 50, 100]},
#              scoring='accuracy', verbose=2)

# %%
gs.best_score_, gs.best_params_
# Out:
# (0.6980496837650002,
#  {'learning_rate': 0.01, 'max_depth': 13, 'one_hot_max_size': 10})

# %% [markdown]
# ## Оценка важности признаков
#
# [Статья](https://towardsdatascience.com/deep-dive-into-catboost-functionalities-for-model-interpretation-7cdef669aeed)

# %%
from sklearn.metrics import log_loss

def logloss(model, X, y):
    return log_loss(y, model.predict_proba(X)[:,1])

def permutation_importances(model, X, y, metric):
    baseline = metric(model, X, y)
    imp = []
    for col in X.columns:
        save = X[col].copy()
        X[col] = np.random.permutation(X[col])
        m = metric(model, X, y)
        X[col] = save
        imp.append(m-baseline)
    return np.array(imp)

# %%
fi_1 = model1.feature_importances_

feature_score = pd.DataFrame(list(zip(Xtest.dtypes.index, fi_1)),
                                    columns=['Feature','Score'])

feature_score = feature_score.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('Standard Importances'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %%
fi_2 = permutation_importances(model1, Xtest, ytest, logloss)

feature_score = pd.DataFrame(list(zip(Xtest.dtypes.index, fi_2)),
                                    columns=['Feature','Score'])

feature_score = feature_score.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

plt.rcParams["figure.figsize"] = (12,7)
ax = feature_score.plot('Feature', 'Score', kind='bar', color='c')
ax.set_title("Feature Importance using {}".format('Permutation Importances'), fontsize = 14)
ax.set_xlabel("features")
plt.show()

# %% [markdown]
# ## Блендинг и стекинг

# %% [markdown]
# В этом подходе предсказания строятся как взвешенная сумма базовых алгоритмов.
#
# Рассмотрим простой пример блендинга градиентного бустинга и линейной регрессии для датасете `load_boston` и оценкой качества через RMSE.

# %% [markdown]
# Поделим выборку на обучающую (60%), тестовую (20%) и валидационную (20%).

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing()
X_init = pd.DataFrame(data.data, columns=data.feature_names)
y_init = data.target

X, X_test, y, y_test = train_test_split(X_init, y_init, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

assert X_init.shape[0] == X_train.shape[0] + X_val.shape[0] + X_test.shape[0]

def rmse(y_true, y_pred):
    error = (y_true - y_pred) ** 2
    return np.sqrt(np.mean(error))

# %% [markdown]
# Посмотрим, какое у нас качество у алгоритмов, если просто обучим на train и проверим качество на test:

# %%
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression

cbm = CatBoostRegressor(iterations=100, max_depth=4, learning_rate=0.01, loss_function='RMSE', logging_level='Silent')
cbm.fit(X_train, y_train)
test_pred_cbm = cbm.predict(X_test)

lr = LinearRegression()
lr.fit(X_train, y_train)
test_pred_lr = lr.predict(X_test)

print("Test RMSE Linear Regression = %.3f" % rmse(y_test, test_pred_lr))
print("Test RMSE Catboost = %.3f" % rmse(y_test, test_pred_cbm))

pred = 0.8 * test_pred_lr + 0.2 * test_pred_cbm

print("Test RMSE mix = %.3f" % rmse(y_test, pred))
# Out:
# Test RMSE Linear Regression = 0.726
# Test RMSE Catboost = 0.816
# Test RMSE mix = 0.713

# %% [markdown]
# Представим новый алгоритм $a(x)$ как взвешенную сумму из базовых алгоритмов:
# $$
#     a(x)
#     =
#     \sum_{n = 1}^{N}
#     w_n b_n(x),
# $$
# где $\sum_{n} w_n =1$ и нам нужно подобрать $w_n$.
#
# Сначала рассмотрим более простой случай, когда пробуем подбирать, с какими весами нам взять предсказания алгоритмов методом перебора пар весов (т.к. у нас только два алгоритма).
#
# Будем веса подбирать на валидации, а проверять качество на тесте.

# %%
def select_weights(y_true, y_pred_1, y_pred_2):
    grid = np.linspace(0, 1, 1000)
    metric = []
    for w_0 in grid:
        w_1 = 1 - w_0
        y_a = w_0 * y_pred_1 + w_1 * y_pred_2
        metric.append([rmse(y_true, y_a), w_0, w_1])
    return metric

# %%
val_pred_cbm = cbm.predict(X_val)
val_pred_lr = lr.predict(X_val)

rmse_blending_train, w_0, w_1 = min(select_weights(y_val, val_pred_cbm, val_pred_lr), key=lambda x: x[0])
rmse_blending_train, w_0, w_1
# Out:
# (0.7142738021013669, 0.24824824824824826, 0.7517517517517518)

# %%
round(rmse(y_test, test_pred_cbm * w_0 +  test_pred_lr * w_1), 3)
# Out:
# 0.728

# %% [markdown]
# Давайте теперь напишем классическую версию блендинга, который выполняется по следующей схеме. Возьмем обучающую и тестовую выборку и разделим обучающую выборку на две части. На первой части обучим базовые алгоритмы, на второй - обучим мета-алгоритм из предсказаний базовых алгоритмов, и потом получим предсказания тестовых мета-признаках.
# <img src='https://alexanderdyakonov.files.wordpress.com/2017/03/stacking.png?w=1400' width=600>

# %% [markdown]
# Посмотрим на все шаги с самого начала, c момента загрузки исходных данных:

# %%
data = fetch_california_housing()
X_init = pd.DataFrame(data.data, columns=data.feature_names)
y_init = data.target

X, X_test, y, y_test = train_test_split(X_init, y_init, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

assert X_init.shape[0] == X_train.shape[0] + X_val.shape[0] + X_test.shape[0]

# %%
from lightgbm import LGBMRegressor

gb = CatBoostRegressor(iterations=100, max_depth=4, learning_rate=0.01, loss_function='RMSE', logging_level='Silent')
gb.fit(X_train, y_train)

lr = LinearRegression()
lr.fit(X_train, y_train)

meta_train_df = pd.DataFrame()
meta_train_df['gb_preds'] = gb.predict(X_val)
meta_train_df['lr_preds'] = lr.predict(X_val)

meta_algo = LGBMRegressor()
meta_algo.fit(meta_train_df, y_val)

meta_pred_df = pd.DataFrame()
meta_pred_df['gb_preds'] = gb.predict(X_test)
meta_pred_df['lr_preds'] = lr.predict(X_test)
test_preds_meta = meta_algo.predict(meta_pred_df)

rmse(y_test, test_preds_meta)
# Out:
# 0.6754321194423076

# %% [markdown]
# Получается, что при блендинге базовые алгоритмы и мета-алгоритм не используют весь объем выборки обучения, что является недостатком. Для повышения качества нужно усреднять несколько стекингов.

# %% [markdown]
# ### Стэкинг на кросс-валидации

# %% [markdown]
# Попробуем реализовать стэкинг. Выборку разбивают на фолды. последовательно перебирая фолды, обучают базовые алгоритмы на всех фолдах, кроме одного, а на оставшемся получают ответы базовых алгоритмов и используют их как значения соответствующих признаков на этом фолде. Для получения мета-признаков объектов тестовой выборки базовые алгоритмы обучают на всей обучающей выборке и берут их ответы на тестовой.
#
# <img src='https://alexanderdyakonov.files.wordpress.com/2017/03/stacking-2b.png?w=1400' width=600>

# %% [markdown]
# Для стэкинга можно пользоваться встроенной имплементацией в sklearn. Возьмем случайный лес и линейную регрессию как базовые алгоритмы, и потом обучим поверх с помощью 10-фолдовой кросс-валидации мета-алгоритм - градиентный бустинг.

# %%
from sklearn.ensemble import StackingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier

estimators = [('rf', RandomForestRegressor(n_estimators=200,random_state=42)),
              ('lr', LinearRegression(),
               'knn',KNeighborsClassifier(n_neighbors=10))]

reg = StackingRegressor(estimators=estimators,
                        cv=10,
                        final_estimator=CatBoostRegressor(iterations=700, max_depth=5, learning_rate=0.01,
                                       loss_function='RMSE', logging_level='Silent'))

reg.fit(X_train, y_train).score(X_test, y_test)
reg_preds = reg.predict(X_test)
round(rmse(y_test, reg_preds), 3)
# Out:
# 0.518
